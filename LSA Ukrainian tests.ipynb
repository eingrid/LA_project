# %%
import gzip
from io import StringIO
import pandas as pd
from datetime import datetime, timedelta
import numpy as np
import re
import string
import json
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import ngrams
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora.dictionary import Dictionary
from gensim import matutils

# %%
def gzip_file_to_documents_list(file_name, languages_filter=['en']):
    with gzip.open(file_name, 'rb') as f:
        decompressed_data = f.read()
    df_data = pd.read_csv(StringIO(str(decompressed_data,'utf-8')), index_col=0)
    documents = df_data[df_data['language'].isin(languages_filter)]['text'].tolist()
    return documents

# %%
def uctd_file_name_by_date(month, day):
    return '0'*int(month < 10) + str(month) + '0'*int(day < 10) + str(day) + "_UkraineCombinedTweetsDeduped.csv.gzip"

# %%
def get_uctd_documents_between_dates(start: str, end: str,
                                     languages_filter=['en'], verbose: int = 0):
    # Dates in the 'YYYY-DD-MM' format
    date_start = datetime.strptime(start, '%Y-%m-%d')
    date_end = datetime.strptime(end, '%Y-%m-%d')
    delta_days = date_end - date_start
    all_documents = []
    for i_d in range(delta_days.days + 1):
        date_current = date_start + timedelta(days=i_d)
        uctd_file_name = uctd_file_name_by_date(date_current.month, date_current.day)
        all_documents += gzip_file_to_documents_list(uctd_file_name, languages_filter=languages_filter)
        if verbose == 1:
            print(f'--Documents for the day {date_current.date()} processed')
    return all_documents

# %%
all_documents_0922_uk = get_uctd_documents_between_dates('2022-09-01','2022-09-30',
                                                         languages_filter=['uk'],verbose=1)
# Out:
# --Documents for the day 2022-09-01 processed
# --Documents for the day 2022-09-02 processed
# --Documents for the day 2022-09-03 processed
# --Documents for the day 2022-09-04 processed
# --Documents for the day 2022-09-05 processed
# --Documents for the day 2022-09-06 processed
# --Documents for the day 2022-09-07 processed
# --Documents for the day 2022-09-08 processed
# --Documents for the day 2022-09-09 processed
# --Documents for the day 2022-09-10 processed
# --Documents for the day 2022-09-11 processed
# --Documents for the day 2022-09-12 processed
# --Documents for the day 2022-09-13 processed
# --Documents for the day 2022-09-14 processed
# --Documents for the day 2022-09-15 processed
# --Documents for the day 2022-09-16 processed
# --Documents for the day 2022-09-17 processed
# --Documents for the day 2022-09-18 processed
# --Documents for the day 2022-09-19 processed
# --Documents for the day 2022-09-20 processed
# --Documents for the day 2022-09-21 processed
# --Documents for the day 2022-09-22 processed
# --Documents for the day 2022-09-23 processed
# --Documents for the day 2022-09-24 processed
# --Documents for the day 2022-09-25 processed
# --Documents for the day 2022-09-26 processed
# --Documents for the day 2022-09-27 processed
# --Documents for the day 2022-09-28 processed
# --Documents for the day 2022-09-29 processed
# --Documents for the day 2022-09-30 processed

# %%
from stop_words import get_stop_words

stop_words = get_stop_words('uk')

# %%
class UkrainianPreprocessor:
    def preprocess_documents(self, documents_list: list, return_strings: bool = True):
        return [self.preprocess(doc, return_string=return_strings) for doc in documents_list]
    
    # Function to preprocess documents
    def preprocess(self, document, return_string: bool = True):
        # Tokenize
        document = self.remove_links_content(document)
        document = self.remove_emails(document)
        document = self.remove_multiple_space(document)
        document = self.remove_hashtags(document)
        document = self.remove_punctuation(document)
        document = self.remove_multiple_space(document)
        
        words = word_tokenize(document.lower())
        # Remove stopwords and punctuations
        filtered_words = [word for word in words if word.isalnum() and not word in stop_words]
        # Lemmatize
        lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
        if return_string:
            return ' '.join(lemmatized_words)
        else:
            return lemmatized_words
    
    def remove_links_content(self, text):
        text = re.sub(r"http\S+", "", text)
        return text
    
    def remove_emails(self, text):
        return re.sub('\S+@\S*\s?', '', text)
    
    def remove_punctuation(self, text):
        """https://stackoverflow.com/a/37221663"""
        table = str.maketrans({key: None for key in string.punctuation})
        return text.translate(table)
    
    def remove_multiple_space(self, text):
        return re.sub("\s\s+", " ", text)

    def remove_hashtags(self, text):
        old_text = text + '\n'
        new_text = text
        while len(new_text) < len(old_text):
            old_text = new_text
            new_text = re.sub('(?<=[\s\n])#\S+\s*$', '', new_text)
        return new_text

# %%
class LSAPipelineUkrainian:
    def __init__(self, documents_list, tf_idf_max_df=1.0, tf_idf_min_df=1,
                 lsa_components: int = 100, svd_n_iter: int = 5,
                 n_top_words: int = 10, ngram_range: tuple = (1, 1),
                 import_preprocessed_documents: bool = False, random_state: int = -1):
        if not import_preprocessed_documents:
            self.import_documents_list = UkrainianPreprocessor().preprocess_documents(documents_list)
        else:
            self.import_documents_list = documents_list
        self.tf_idf_max_df = tf_idf_max_df
        self.tf_idf_min_df = tf_idf_min_df
        self.lsa_components = lsa_components
        self.svd_n_iter = svd_n_iter
        self.n_top_words = n_top_words
        self.ngram_range = ngram_range
        self.random_state = random_state
        self.coherence_texts_calculated = False

    def run_topics_detection(self):
        tfidf_documents = self.TF_IDF()
        self.TruncatedSVD(tfidf_documents)
        self.topics = self.find_topics()
        return self.topics

    def transform_documents(self, new_documents_list: list):
        return list(map(np.argmax, self.svd_model.transform(
            self.tfidf_vectorizer.transform(new_documents_list))))

    def import_ready_documents(self, documents_list, texts, dictionary, corpus):
        self.import_documents_list = documents_list
        self.texts = texts
        self.dictionary = dictionary
        self.corpus = corpus
        self.coherence_texts_calculated = True

    def TF_IDF(self):
        self.tfidf_vectorizer = TfidfVectorizer(max_df=self.tf_idf_max_df,
                                                min_df=self.tf_idf_min_df,
                                                ngram_range=self.ngram_range,
                                                stop_words=stop_words)
        return self.tfidf_vectorizer.fit_transform(self.import_documents_list)
        # tfidf_feature_names = self.tfidf_vectorizer.get_feature_names_out()
    
    def TruncatedSVD(self, tfidf_documents):
        if self.random_state != -1:
            self.svd_model = TruncatedSVD(n_components=self.lsa_components,
                                 n_iter=self.svd_n_iter, random_state=self.random_state)
        else:
            self.svd_model = TruncatedSVD(n_components=self.lsa_components,
                                 n_iter=self.svd_n_iter)
        self.svd_model.fit_transform(tfidf_documents)

    def find_topics(self):
        # Extract the top words for each topic
        topics = []
        tfidf_feature_names = self.tfidf_vectorizer.get_feature_names_out()
        for topic_idx, topic in enumerate(self.svd_model.components_):
            top_features_ind = topic.argsort()[:-self.n_top_words - 1:-1]
            top_features = [tfidf_feature_names[i] for i in top_features_ind]
            topics.append(top_features)
        return topics

    def calculate_coherence_score(self, recalculate_texts: bool = False, verbose: int = 0):
        if not self.coherence_texts_calculated or recalculate_texts:
            self.calculate_coherence_texts(verbose=verbose)
        # Calculate the coherence score using Gensim
        coherence_model = CoherenceModel(topics=self.topics,
                                         texts=self.texts,
                                         dictionary=self.dictionary,
                                         coherence='c_v')
        if verbose == 1:
            print(f'--Calculating the coherence score')
        self.coherence_score = coherence_model.get_coherence()
        return self.coherence_score

    def calculate_coherence_texts(self, verbose: int = 0):
        # Convert the list of top words into a list of lists of words
        tfidf_feature_names = set(self.tfidf_vectorizer.get_feature_names_out())
        if verbose == 1:
            print(f'--Starting forming the texts')
        self.texts = [[word for word in doc.lower().split() if (
            word in tfidf_feature_names)] for doc in self.import_documents_list]
        # Create a Gensim dictionary
        if verbose == 1:
            print(f'--Creating the Gensim dectionary')
        self.dictionary = Dictionary(self.texts)
        # Convert the dictionary and the corpus
        if verbose == 1:
            print(f'--Converting to the corpus')
        self.corpus = [dictionary.doc2bow(text) for text in self.texts]
        self.coherence_texts_calculated = True

# %%
def tokenize_ngrams(document, n_g):
    return [' '.join(ngram) for ngram in ngrams(document.lower().split(), n_g)]

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /home/oleksii/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/oleksii/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemmatizer = WordNetLemmatizer()

# %%
LSAPipeline = LSAPipelineUkrainian(all_documents_0922_uk, tf_idf_max_df=0.9, tf_idf_min_df=4,
                                 lsa_components=5, svd_n_iter=5,
                                 n_top_words=10, ngram_range=(1,2),
                                 random_state=47)
topics = LSAPipeline.run_topics_detection()
# Out:
# /home/oleksii/UCU/ucu_env/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['дев', 'ласка', 'разу', 'ятий', 'ятнадцятий', 'ятнадцять', 'ять', 'ім'] not in stop_words.
#   warnings.warn(

# %%
topics
# Out:
# [['ебать',
#   'путін ukrainian',
#   'ебать путін',
#   'ідіть ебать',
#   'ідіть',
#   'ukrainian',
#   'путін',
#   'україні',
#   'ukraine',
#   'ідіть нахуй'],
#  ['слава',
#   'україні',
#   'слава україні',
#   'зсу',
#   'слава зсу',
#   'героям',
#   'україні слава',
#   'ukraine',
#   'героям слава',
#   'україні героям'],
#  ['війна анімація',
#   'отже війна',
#   'анімація',
#   'отже',
#   'війна',
#   'шо',
#   'ukraine',
#   'закінчиться',
#   'war',
#   'україна'],
#  ['підписатись',
#   'підписатись адвокат',
#   'дня соловїною',
#   'соловїною підписатись',
#   'соловїною',
#   'адвокат',
#   'дня',
#   'кожного дня',
#   'кожного',
#   'гарного'],
#  ['фото',
#   'ukraine',
#   'что',
#   'только что',
#   'что опубликовано',
#   'опубликовано фото',
#   'опубликовано',
#   'только',
#   'kyiv',
#   'kyiv ukraine']]

# %%
tfidf_feature_names = set(LSAPipeline.tfidf_vectorizer.get_feature_names_out())
preprocessed_documents = LSAPipeline.import_documents_list

# %%
all_documents_0922_uk[0]
# Out:
# 'Міноборони передало до парламенту пропозиції змін до закону про військовий обов’язок щодо добровільності постановки на військовий облік жінок https://t.co/Sh7QfRjxqG #ukraine'

# %%
preprocessed_documents[0]
# Out:
# 'міноборони передало до парламенту пропозиції змін до закону про військовий обов язок щодо добровільності постановки на військовий облік жінок'

# %%
# Convert the list of ngrams into a list of lists of words
texts_v4 = [[word for word in doc.lower().split() if (
    word in tfidf_feature_names)] + tokenize_ngrams(doc, 2) for doc in preprocessed_documents]

# Create a Gensim dictionary
dictionary_v4 = Dictionary(texts_v4)

# Convert the dictionary and the corpus
corpus_v4 = [dictionary_v4.doc2bow(text) for text in texts_v4]

# %%
# Calculate the coherence score using Gensim
coherence_model = CoherenceModel(topics=topics,
                                 texts=texts_v4,
                                 dictionary=dictionary_v4,
                                 corpus=corpus_v4,
                                 coherence='c_v')
coherence_score = coherence_model.get_coherence()

print('Coherence Score:', coherence_score)
# Out:
# Coherence Score: 0.6321149420077983

# %% [markdown]
# ## 1- and 2-grams: optimal topics number
#
# Model that uses both 1- and 2-grams for the different topics numbers for the data for September 2022 in Ukrainian language.

# %%
topic_numbers_12grams = list(range(2,15)) + [20,30,40,50,100,150,200]
coherences_12grams = []
predicted_topics_counts_12grams = []
for topic_number in topic_numbers_12grams:
    LSAPipeline = LSAPipelineUkrainian(all_documents_0922_uk, tf_idf_max_df=0.9, tf_idf_min_df=4,
                                 lsa_components=topic_number, svd_n_iter=5,
                                 n_top_words=10, ngram_range=(1,2),
                                 random_state=47)
    topics_12grams = LSAPipeline.run_topics_detection()
    tfidf_feature_names = set(LSAPipeline.tfidf_vectorizer.get_feature_names_out())
    # Calculate the coherence score using Gensim
    coherence_model = CoherenceModel(topics=topics_12grams,
                                     texts=texts_v4,
                                     dictionary=dictionary_v4,
                                     corpus=corpus_v4,
                                     coherence='c_v')
    coherence_score = coherence_model.get_coherence()
    predicted_topics = LSAPipeline.transform_documents(LSAPipeline.import_documents_list)
    predicted_topics_count = [predicted_topics.count(x) for x in np.sort(np.unique(predicted_topics))]
    
    print(f'--Topic number {topic_number} coherence score: {coherence_score}')
    coherences_12grams.append(coherence_score)
    predicted_topics_counts_12grams.append(predicted_topics_count)
# Out:
# --Topic number 2 coherence score: 0.6809041134227105
# --Topic number 3 coherence score: 0.5525279450253504
# --Topic number 4 coherence score: 0.53230184193736
# --Topic number 5 coherence score: 0.6321149420077983
# --Topic number 6 coherence score: 0.6111898822710554
# --Topic number 7 coherence score: 0.6635846666650449
# --Topic number 8 coherence score: 0.6211509734536742
# --Topic number 9 coherence score: 0.6090182257767875
# --Topic number 10 coherence score: 0.5720475065902724
# --Topic number 11 coherence score: 0.5773671073803661
# --Topic number 12 coherence score: 0.546130195091591
# --Topic number 13 coherence score: 0.511296396917588
# --Topic number 14 coherence score: 0.5187133260182518
# --Topic number 20 coherence score: 0.4991199245235597
# --Topic number 30 coherence score: 0.45816826394032256
# --Topic number 40 coherence score: 0.39987153328398434
# --Topic number 50 coherence score: 0.3797382908369695
# --Topic number 100 coherence score: 0.3412006596560729
# --Topic number 150 coherence score: 0.33211330566403036
# --Topic number 200 coherence score: 0.3336017376096423

# %%
dmddnt

# %%
topic_numbers_12grams = list(range(2,15)) + [20,30,40,50,100,150,200]
coherences_12grams = []
predicted_topics_counts_12grams = []
for topic_number in topic_numbers_12grams:
    LSAPipeline = LSAPipelineUkrainian(preprocessed_documents, tf_idf_max_df=0.9, tf_idf_min_df=4,
                                 lsa_components=topic_number, svd_n_iter=5,
                                 n_top_words=10, ngram_range=(1,2),
                                 import_preprocessed_documents=True,
                                 random_state=47)
    topics_12grams = LSAPipeline.run_topics_detection()
    tfidf_feature_names = set(LSAPipeline.tfidf_vectorizer.get_feature_names_out())
    # Calculate the coherence score using Gensim
    coherence_model = CoherenceModel(topics=topics_12grams,
                                     texts=texts_v4,
                                     dictionary=dictionary_v4,
                                     corpus=corpus_v4,
                                     coherence='c_v')
    coherence_score = coherence_model.get_coherence()
    predicted_topics = LSAPipeline.transform_documents(LSAPipeline.import_documents_list)
    predicted_topics_count = [predicted_topics.count(x) for x in np.sort(np.unique(predicted_topics))]
    
    print(f'--Topic number {topic_number} coherence score: {coherence_score}')
    coherences_12grams.append(coherence_score)
    predicted_topics_counts_12grams.append(predicted_topics_count)
# Out:
# --Topic number 2 coherence score: 0.6809041134227105
# --Topic number 3 coherence score: 0.5525279450253504

# %%
with open('coherences_12grams_uk.json','w') as json_file:
    json.dump({'coherences': coherences_12grams,
               'predicted_topics': predicted_topics_counts_12grams}, json_file)

# %%
plt.plot(topic_numbers_12grams, coherences_12grams)
plt.title('Coherence for different n_topics | 12grams model | Ukrainian')
plt.xlabel('Topics number')
plt.ylabel('Coherence (c_v) score')
plt.grid()
plt.show()

# %%
plt.plot(topic_numbers_12grams, coherences_12grams)
plt.title('Coherence for different n_topics | 12grams model | Ukrainian')
plt.xlabel('Topics number')
plt.ylabel('Coherence (c_v) score')
plt.grid()
plt.show()

# %% [markdown]
# # New preprocessing
#
# The old lemmatization and tokenization procedures for Ukrainian don't seem ideal. Let's improve them a bit and observe how it impacts the performance.

# %%
all_documents_0922_uk[:5]
# Out:
# ['Міноборони передало до парламенту пропозиції змін до закону про військовий обов’язок щодо добровільності постановки на військовий облік жінок https://t.co/Sh7QfRjxqG #ukraine',
#  'Якшо чесно, я сумніваюсь в її реальності✨🤲🏼 https://t.co/Lp4e31WhJ2',
#  'Додав трохи фотошопу... Джонні не знав на що підписався https://t.co/7id1m1Zt68',
#  'Дива трапляються... Дякую за запрошення Alessio Carbone, хореограф у Артему Шошину та партнеру Олексію Потьомкіну 💕💕💕💕 🇺🇦🇺🇦🇮🇹🇮🇹#ballet #balletukraine #yevheniiakorshunova #oleksiipotomkin #artemshoshyn #itali #ballerina #Ukraine️ #Ukraine️ https://t.co/XozJ9ANtAZ',
#  'о третій ночі зловила повітряну тривогу, така гучна, я трошки не була готова ще🥲']

# %%
UkrainianPreprocessor().preprocess_documents(all_documents_0922_uk[:5])
# Out:
# ['міноборони передало до парламенту пропозиції змін до закону про військовий обов язок щодо добровільності постановки на військовий облік жінок',
#  'якшо чесно я сумніваюсь в її',
#  'додав трохи фотошопу джонні не знав на що підписався',
#  'дива трапляються дякую за запрошення alessio carbone хореограф у артему шошину та партнеру олексію потьомкіну',
#  'о третій ночі зловила повітряну тривогу така гучна я трошки не була готова']

# %% [markdown]
# New lemmatizer using the [stanza](https://stanfordnlp.github.io/stanza/) library:

# %%
import stanza

# %%
stanza.download('uk')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# 2024-03-15 19:24:49 INFO: Downloading default packages for language: uk (Ukrainian) ...
# 2024-03-15 19:24:50 INFO: File exists: /home/oleksii/stanza_resources/uk/default.zip
# 2024-03-15 19:24:53 INFO: Finished downloading models and saved to /home/oleksii/stanza_resources.

# %%
stanza_pip = stanza.Pipeline(lang='uk', processors='tokenize,mwt,pos,lemma')
# Out:
# 2024-03-15 19:24:53 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# 2024-03-15 19:24:54 INFO: Loading these models for language: uk (Ukrainian):
# ===========================
# | Processor | Package     |
# ---------------------------
# | tokenize  | iu          |
# | mwt       | iu          |
# | pos       | iu_charlm   |
# | lemma     | iu_nocharlm |
# ===========================
#
# 2024-03-15 19:24:54 INFO: Using device: cpu
# 2024-03-15 19:24:54 INFO: Loading: tokenize
# 2024-03-15 19:24:54 INFO: Loading: mwt
# 2024-03-15 19:24:54 INFO: Loading: pos
# 2024-03-15 19:24:55 INFO: Loading: lemma
# 2024-03-15 19:24:55 INFO: Done loading processors!

# %%
all_documents_0922_uk[0]
# Out:
# 'Міноборони передало до парламенту пропозиції змін до закону про військовий обов’язок щодо добровільності постановки на військовий облік жінок https://t.co/Sh7QfRjxqG #ukraine'

# %%
doc = stanza_pip(all_documents_0922_uk[0])
print(*[f'word: {word.text+" ":15}\tlemma: {word.lemma}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# word: Міноборони     	lemma: міноборон
# word: передало       	lemma: передати
# word: до             	lemma: до
# word: парламенту     	lemma: парламент
# word: пропозиції     	lemma: пропозиція
# word: змін           	lemma: зміна
# word: до             	lemma: до
# word: закону         	lemma: закон
# word: про            	lemma: про
# word: військовий     	lemma: військовий
# word: обов’язок      	lemma: обов’язка
# word: щодо           	lemma: щодо
# word: добровільності 	lemma: добровільність
# word: постановки     	lemma: постановка
# word: на             	lemma: на
# word: військовий     	lemma: військовий
# word: облік          	lemma: облік
# word: жінок          	lemma: жінка
# word: https://t.co/Sh7QfRjxqG 	lemma: https://t.co/Sh7QfRjxqG
# word: #              	lemma: #
# word: ukraine        	lemma: ukraine
# Міноборони передало до парламенту пропозиції змін до закону про військовий обов’язок щодо добровільності постановки на військовий облік жінок https://t.co/Sh7QfRjxqG #ukraine

# %%
print([word for sent in doc.sentences for word in sent.words])
# Out:
# [{
#   "id": 1,
#   "text": "Міноборони",
#   "lemma": "міноборон",
#   "upos": "NOUN",
#   "xpos": "Ncmpnn",
#   "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur",
#   "start_char": 0,
#   "end_char": 10
# }, {
#   "id": 2,
#   "text": "передало",
#   "lemma": "передати",
#   "upos": "VERB",
#   "xpos": "Vmeis-sn",
#   "feats": "Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin",
#   "start_char": 11,
#   "end_char": 19
# }, {
#   "id": 3,
#   "text": "до",
#   "lemma": "до",
#   "upos": "ADP",
#   "xpos": "Spsg",
#   "feats": "Case=Gen",
#   "start_char": 20,
#   "end_char": 22
# }, {
#   "id": 4,
#   "text": "парламенту",
#   "lemma": "парламент",
#   "upos": "NOUN",
#   "xpos": "Ncmsgn",
#   "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#   "start_char": 23,
#   "end_char": 33
# }, {
#   "id": 5,
#   "text": "пропозиції",
#   "lemma": "пропозиція",
#   "upos": "NOUN",
#   "xpos": "Ncfpan",
#   "feats": "Animacy=Inan|Case=Acc|Gender=Fem|Number=Plur",
#   "start_char": 34,
#   "end_char": 44
# }, {
#   "id": 6,
#   "text": "змін",
#   "lemma": "зміна",
#   "upos": "NOUN",
#   "xpos": "Ncfpgn",
#   "feats": "Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur",
#   "start_char": 45,
#   "end_char": 49
# }, {
#   "id": 7,
#   "text": "до",
#   "lemma": "до",
#   "upos": "ADP",
#   "xpos": "Spsg",
#   "feats": "Case=Gen",
#   "start_char": 50,
#   "end_char": 52
# }, {
#   "id": 8,
#   "text": "закону",
#   "lemma": "закон",
#   "upos": "NOUN",
#   "xpos": "Ncmsgn",
#   "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#   "start_char": 53,
#   "end_char": 59
# }, {
#   "id": 9,
#   "text": "про",
#   "lemma": "про",
#   "upos": "ADP",
#   "xpos": "Spsa",
#   "feats": "Case=Acc",
#   "start_char": 60,
#   "end_char": 63
# }, {
#   "id": 10,
#   "text": "військовий",
#   "lemma": "військовий",
#   "upos": "ADJ",
#   "xpos": "Ao-msafn",
#   "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#   "start_char": 64,
#   "end_char": 74
# }, {
#   "id": 11,
#   "text": "обов’язок",
#   "lemma": "обов’язка",
#   "upos": "NOUN",
#   "xpos": "Ncmsan",
#   "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#   "start_char": 75,
#   "end_char": 84
# }, {
#   "id": 12,
#   "text": "щодо",
#   "lemma": "щодо",
#   "upos": "ADP",
#   "xpos": "Spsg",
#   "feats": "Case=Gen",
#   "start_char": 85,
#   "end_char": 89
# }, {
#   "id": 13,
#   "text": "добровільності",
#   "lemma": "добровільність",
#   "upos": "NOUN",
#   "xpos": "Ncfsgn",
#   "feats": "Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing",
#   "start_char": 90,
#   "end_char": 104
# }, {
#   "id": 14,
#   "text": "постановки",
#   "lemma": "постановка",
#   "upos": "NOUN",
#   "xpos": "Ncfsgn",
#   "feats": "Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing",
#   "start_char": 105,
#   "end_char": 115
# }, {
#   "id": 15,
#   "text": "на",
#   "lemma": "на",
#   "upos": "ADP",
#   "xpos": "Spsa",
#   "feats": "Case=Acc",
#   "start_char": 116,
#   "end_char": 118
# }, {
#   "id": 16,
#   "text": "військовий",
#   "lemma": "військовий",
#   "upos": "ADJ",
#   "xpos": "Ao-msafn",
#   "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#   "start_char": 119,
#   "end_char": 129
# }, {
#   "id": 17,
#   "text": "облік",
#   "lemma": "облік",
#   "upos": "NOUN",
#   "xpos": "Ncmsan",
#   "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#   "start_char": 130,
#   "end_char": 135
# }, {
#   "id": 18,
#   "text": "жінок",
#   "lemma": "жінка",
#   "upos": "NOUN",
#   "xpos": "Ncfpgy",
#   "feats": "Animacy=Anim|Case=Gen|Gender=Fem|Number=Plur",
#   "start_char": 136,
#   "end_char": 141
# }, {
#   "id": 19,
#   "text": "https://t.co/Sh7QfRjxqG",
#   "lemma": "https://t.co/Sh7QfRjxqG",
#   "upos": "SYM",
#   "xpos": "X",
#   "start_char": 142,
#   "end_char": 165
# }, {
#   "id": 20,
#   "text": "#",
#   "lemma": "#",
#   "upos": "SYM",
#   "xpos": "X",
#   "start_char": 166,
#   "end_char": 167
# }, {
#   "id": 21,
#   "text": "ukraine",
#   "lemma": "ukraine",
#   "upos": "X",
#   "xpos": "X",
#   "feats": "Foreign=Yes",
#   "start_char": 167,
#   "end_char": 174
# }]

# %%
print([word.lemma for sent in doc.sentences for word in sent.words])
# Out:
# ['міноборон', 'передати', 'до', 'парламент', 'пропозиція', 'зміна', 'до', 'закон', 'про', 'військовий', 'обов’язка', 'щодо', 'добровільність', 'постановка', 'на', 'військовий', 'облік', 'жінка', 'https://t.co/Sh7QfRjxqG', '#', 'ukraine']

# %%
class UkrainianPreprocessor_v2:
    def preprocess_documents(self, documents_list: list, return_strings: bool = True):
        return [self.preprocess(doc, return_string=return_strings) for doc in documents_list]
    
    # Function to preprocess documents
    def preprocess(self, document, return_string: bool = True):
        # Clean the document
        document = self.remove_links_content(document)
        document = self.remove_emails(document)
        document = self.remove_multiple_space(document)
        document = self.remove_hashtags(document)
        document = self.remove_punctuation(document)
        document = self.remove_multiple_space(document)
        
        # Tokenize and lemmatize
        processed_document = stanza_pip(document.lower())
        lemmatized_words = [word.lemma for sent in processed_document.sentences for word in sent.words]
        # Remove stopwords and punctuations
        filtered_words = [word for word in lemmatized_words if word.isalnum() and not word in stop_words]
        if return_string:
            return ' '.join(filtered_words)
        else:
            return filtered_words
    
    def remove_links_content(self, text):
        text = re.sub(r"http\S+", "", text)
        return text
    
    def remove_emails(self, text):
        return re.sub('\S+@\S*\s?', '', text)
    
    def remove_punctuation(self, text):
        """https://stackoverflow.com/a/37221663"""
        table = str.maketrans({key: None for key in string.punctuation})
        return text.translate(table)
    
    def remove_multiple_space(self, text):
        return re.sub("\s\s+", " ", text)

    def remove_hashtags(self, text):
        old_text = text + '\n'
        new_text = text
        while len(new_text) < len(old_text):
            old_text = new_text
            new_text = re.sub('(?<=[\s\n])#\S+\s*$', '', new_text)
        return new_text

# %%
# Old and preprocessing comparison
for i_d, document in enumerate(all_documents_0922_uk[:5]):
    print(f'--Document {i_d}:')
    print(f'--Old processing: {UkrainianPreprocessor().preprocess_documents([document])[0]}')
    print(f'--New processing: {UkrainianPreprocessor_v2().preprocess_documents([document])[0]}\n')
# Out:
# --Document 0:
# --Old processing: міноборони передало до парламенту пропозиції змін до закону про військовий обов язок щодо добровільності постановки на військовий облік жінок
# --New processing: міноборони передати до парламент пропозиція зміна до закон про військовий обов’язка щодо добровільність постановка на військовий облік жінка
#
# --Document 1:
# --Old processing: якшо чесно я сумніваюсь в її
# --New processing: якшо чесно я сумніватися в її реальності✨🤲 🏼
#
# --Document 2:
# --Old processing: додав трохи фотошопу джонні не знав на що підписався
# --New processing: додати трохи фотошоп джоння не знати на що підписатися
#
# --Document 3:
# --Old processing: дива трапляються дякую за запрошення alessio carbone хореограф у артему шошину та партнеру олексію потьомкіну
# --New processing: диво траплятися дякувати за запрошення alessio carbone хореограф у артем шошин та партнер олексія потьомкін 💕💕💕💕 🇺🇦🇺🇦🇮🇹🇮 🇹ballet
#
# --Document 4:
# --Old processing: о третій ночі зловила повітряну тривогу така гучна я трошки не була готова
# --New processing: о третій ніч зловити повітряний тривіг такий гучний я трошки не бути готовий ще 🥲

# %%
# The new preprocessing class is now our main one
class UkrainianPreprocessor:
    def preprocess_documents(self, documents_list: list,
                             return_strings: bool = True,
                             verbose: int = 1):
        preprocessed_documents = []
        for i_d, doc in enumerate(documents_list):
            preprocessed_documents.append(self.preprocess(doc,
                                                          return_string=return_strings))
            if (verbose == 1) and ((i_d == 0) or ((i_d + 1)%100 == 0)):
                print(f'--Preprocessed documents: {i_d+1}/{len(documents_list)}')
        return preprocessed_documents
    
    # Function to preprocess documents
    def preprocess(self, document, return_string: bool = True):
        # Clean the document
        document = self.remove_links_content(document)
        document = self.remove_emails(document)
        document = self.remove_multiple_space(document)
        document = self.remove_hashtags(document)
        document = self.remove_punctuation(document)
        document = self.remove_multiple_space(document)
        
        # Tokenize and lemmatize
        processed_document = stanza_pip(document.lower())
        lemmatized_words = [word.lemma for sent in processed_document.sentences for word in sent.words]
        # Remove stopwords and punctuations
        filtered_words = [word for word in lemmatized_words if word.isalnum() and not word in stop_words]
        if return_string:
            return ' '.join(filtered_words)
        else:
            return filtered_words
    
    def remove_links_content(self, text):
        text = re.sub(r"http\S+", "", text)
        return text
    
    def remove_emails(self, text):
        return re.sub('\S+@\S*\s?', '', text)
    
    def remove_punctuation(self, text):
        """https://stackoverflow.com/a/37221663"""
        table = str.maketrans({key: None for key in string.punctuation})
        return text.translate(table)
    
    def remove_multiple_space(self, text):
        return re.sub("\s\s+", " ", text)

    def remove_hashtags(self, text):
        old_text = text + '\n'
        new_text = text
        while len(new_text) < len(old_text):
            old_text = new_text
            new_text = re.sub('(?<=[\s\n])#\S+\s*$', '', new_text)
        return new_text

# %%
LSAPipeline_new = LSAPipelineUkrainian(all_documents_0922_uk, tf_idf_max_df=0.9, tf_idf_min_df=4,
                                 lsa_components=5, svd_n_iter=5,
                                 n_top_words=10, ngram_range=(1,2),
                                 random_state=47)
topics = LSAPipeline_new.run_topics_detection()
# Out:
# --Preprocessed documents: 1/98087
# --Preprocessed documents: 100/98087
# --Preprocessed documents: 200/98087
# --Preprocessed documents: 300/98087
# --Preprocessed documents: 400/98087
# --Preprocessed documents: 500/98087
# --Preprocessed documents: 600/98087
# --Preprocessed documents: 700/98087
# --Preprocessed documents: 800/98087
# --Preprocessed documents: 900/98087
# --Preprocessed documents: 1000/98087
# --Preprocessed documents: 1100/98087
# --Preprocessed documents: 1200/98087
# --Preprocessed documents: 1300/98087
# --Preprocessed documents: 1400/98087
# --Preprocessed documents: 1500/98087
# --Preprocessed documents: 1600/98087
# --Preprocessed documents: 1700/98087
# --Preprocessed documents: 1800/98087
# --Preprocessed documents: 1900/98087
# --Preprocessed documents: 2000/98087
# --Preprocessed documents: 2100/98087
# --Preprocessed documents: 2200/98087
# --Preprocessed documents: 2300/98087
# --Preprocessed documents: 2400/98087
# --Preprocessed documents: 2500/98087
# --Preprocessed documents: 2600/98087
# --Preprocessed documents: 2700/98087
# --Preprocessed documents: 2800/98087
# --Preprocessed documents: 2900/98087
# --Preprocessed documents: 3000/98087
# --Preprocessed documents: 3100/98087
# --Preprocessed documents: 3200/98087
# --Preprocessed documents: 3300/98087
# --Preprocessed documents: 3400/98087
# --Preprocessed documents: 3500/98087
# --Preprocessed documents: 3600/98087
# --Preprocessed documents: 3700/98087
# --Preprocessed documents: 3800/98087
# --Preprocessed documents: 3900/98087
# --Preprocessed documents: 4000/98087
# --Preprocessed documents: 4100/98087
# --Preprocessed documents: 4200/98087
# --Preprocessed documents: 4300/98087
# --Preprocessed documents: 4400/98087
# --Preprocessed documents: 4500/98087
# --Preprocessed documents: 4600/98087
# --Preprocessed documents: 4700/98087
# --Preprocessed documents: 4800/98087
# --Preprocessed documents: 4900/98087
# --Preprocessed documents: 5000/98087
# --Preprocessed documents: 5100/98087
# --Preprocessed documents: 5200/98087
# --Preprocessed documents: 5300/98087
# --Preprocessed documents: 5400/98087
# --Preprocessed documents: 5500/98087
# --Preprocessed documents: 5600/98087
# --Preprocessed documents: 5700/98087
# --Preprocessed documents: 5800/98087
# --Preprocessed documents: 5900/98087
# --Preprocessed documents: 6000/98087
# --Preprocessed documents: 6100/98087
# --Preprocessed documents: 6200/98087
# --Preprocessed documents: 91200/98087
# --Preprocessed documents: 91300/98087
# --Preprocessed documents: 91400/98087
# --Preprocessed documents: 91500/98087
# --Preprocessed documents: 91600/98087
# --Preprocessed documents: 91700/98087
# --Preprocessed documents: 91800/98087
# --Preprocessed documents: 91900/98087
# --Preprocessed documents: 92000/98087
# --Preprocessed documents: 92100/98087
# --Preprocessed documents: 92200/98087
# --Preprocessed documents: 92300/98087
# --Preprocessed documents: 92400/98087
# --Preprocessed documents: 92500/98087
# --Preprocessed documents: 92600/98087
# --Preprocessed documents: 92700/98087
# --Preprocessed documents: 92800/98087
# --Preprocessed documents: 92900/98087
# --Preprocessed documents: 93000/98087
# --Preprocessed documents: 93100/98087
# --Preprocessed documents: 93200/98087
# --Preprocessed documents: 93300/98087
# --Preprocessed documents: 93400/98087
# --Preprocessed documents: 93500/98087
# --Preprocessed documents: 93600/98087
# --Preprocessed documents: 93700/98087
# --Preprocessed documents: 93800/98087
# --Preprocessed documents: 93900/98087
# --Preprocessed documents: 94000/98087
# --Preprocessed documents: 94100/98087
# --Preprocessed documents: 94200/98087
# --Preprocessed documents: 94300/98087
# --Preprocessed documents: 94400/98087
# --Preprocessed documents: 94500/98087
# --Preprocessed documents: 94600/98087
# --Preprocessed documents: 94700/98087
# --Preprocessed documents: 94800/98087
# --Preprocessed documents: 94900/98087
# --Preprocessed documents: 95000/98087
# --Preprocessed documents: 95100/98087
# --Preprocessed documents: 95200/98087
# --Preprocessed documents: 95300/98087
# --Preprocessed documents: 95400/98087
# --Preprocessed documents: 95500/98087
# --Preprocessed documents: 95600/98087
# --Preprocessed documents: 95700/98087
# --Preprocessed documents: 95800/98087
# --Preprocessed documents: 95900/98087
# --Preprocessed documents: 96000/98087
# --Preprocessed documents: 96100/98087
# --Preprocessed documents: 96200/98087
# --Preprocessed documents: 96300/98087
# --Preprocessed documents: 96400/98087
# --Preprocessed documents: 96500/98087
# --Preprocessed documents: 96600/98087
# --Preprocessed documents: 96700/98087
# --Preprocessed documents: 96800/98087
# --Preprocessed documents: 96900/98087
# --Preprocessed documents: 97000/98087
# --Preprocessed documents: 97100/98087
# --Preprocessed documents: 97200/98087
# --Preprocessed documents: 97300/98087
# --Preprocessed documents: 97400/98087
# --Preprocessed documents: 97500/98087
# --Preprocessed documents: 97600/98087
# --Preprocessed documents: 97700/98087
# --Preprocessed documents: 97800/98087
# --Preprocessed documents: 97900/98087
# --Preprocessed documents: 98000/98087

# %%
with open('preprocessed_documents_092022_uk_new.json','w') as json_file:
    json.dump({'preprocessed_documents': LSAPipeline_new.import_documents_list}, json_file)

# %%
topics
# Out:
# [['путін ukrainian',
#   'ебать путін',
#   'іти ебать',
#   'ебать',
#   'ukrainian',
#   'іти',
#   'путін',
#   'україна',
#   'війна',
#   'росія'],
#  ['дякувати',
#   'україна',
#   'слава',
#   'зса',
#   'те',
#   'приємно',
#   'пане',
#   'знати',
#   'підтримка',
#   'слава україна'],
#  ['україна',
#   'слава',
#   'слава україна',
#   'зса',
#   'війна',
#   'ukraine',
#   'герой',
#   'свій',
#   'росія',
#   'російський'],
#  ['війна',
#   'отже війна',
#   'війна анімація',
#   'анімація',
#   'отже',
#   'шо',
#   'те',
#   'свій',
#   'знати',
#   'бо'],
#  ['підписатися адвокат',
#   'соловїна підписатися',
#   'соловїна',
#   'адвокат',
#   'підписатися',
#   'шо',
#   'підписатися via',
#   'via',
#   'робити',
#   'бо']]

# %%
tfidf_feature_names = set(LSAPipeline.tfidf_vectorizer.get_feature_names_out())
preprocessed_documents = LSAPipeline.import_documents_list

# %%
# Convert the list of ngrams into a list of lists of words
texts_v5 = [[word for word in doc.lower().split() if (
    word in tfidf_feature_names)] + tokenize_ngrams(doc, 2) for doc in preprocessed_documents]

# Create a Gensim dictionary
dictionary_v5 = Dictionary(texts_v5)

# Convert the dictionary and the corpus
corpus_v5 = [dictionary_v5.doc2bow(text) for text in texts_v5]

# %%
# Calculate the coherence score using Gensim
coherence_model = CoherenceModel(topics=topics,
                                 texts=texts_v5,
                                 dictionary=dictionary_v5,
                                 corpus=corpus_v5,
                                 coherence='c_v')
coherence_score = coherence_model.get_coherence()

print('Coherence Score:', coherence_score)
# Out:
# Coherence Score: 0.46021206442234375

# %% [markdown]
# ## 1- and 2-grams with the new processing: optimal topics number
#
# Model that uses both 1- and 2-grams with the new preprocessing for the different topics numbers for the data for September 2022 in Ukrainian language.

# %%
topic_numbers_12grams = list(range(2,15)) + [20,30,40,50,100,150,200]
coherences_12grams = []
predicted_topics_counts_12grams = []
for topic_number in topic_numbers_12grams:
    LSAPipeline = LSAPipelineUkrainian(preprocessed_documents, tf_idf_max_df=0.9, tf_idf_min_df=4,
                                 lsa_components=topic_number, svd_n_iter=5,
                                 n_top_words=10, ngram_range=(1,2),
                                 import_preprocessed_documents=True, random_state=47)
    topics_12grams = LSAPipeline.run_topics_detection()
    tfidf_feature_names = set(LSAPipeline.tfidf_vectorizer.get_feature_names_out())
    # Calculate the coherence score using Gensim
    coherence_model = CoherenceModel(topics=topics_12grams,
                                     texts=texts_v5,
                                     dictionary=dictionary_v5,
                                     corpus=corpus_v5,
                                     coherence='c_v')
    coherence_score = coherence_model.get_coherence()
    predicted_topics = LSAPipeline.transform_documents(LSAPipeline.import_documents_list)
    predicted_topics_count = [predicted_topics.count(x) for x in np.sort(np.unique(predicted_topics))]
    
    print(f'--Topic number {topic_number} coherence score: {coherence_score}')
    coherences_12grams.append(coherence_score)
    predicted_topics_counts_12grams.append(predicted_topics_count)
# Out:
# --Topic number 2 coherence score: 0.2905581531479207
# --Topic number 3 coherence score: 0.45424678594613993
# --Topic number 4 coherence score: 0.4150800549832757
# --Topic number 5 coherence score: 0.39171220461669504
# --Topic number 6 coherence score: 0.36887492764260915
# --Topic number 7 coherence score: 0.3380657789739235
# --Topic number 8 coherence score: 0.3546118252105634
# --Topic number 9 coherence score: 0.32192364300863274
# --Topic number 10 coherence score: 0.41119238838525973
# --Topic number 11 coherence score: 0.3754787345168653
# --Topic number 12 coherence score: 0.43095501686306004
# --Topic number 13 coherence score: 0.4285081254892302
# --Topic number 14 coherence score: 0.4132330129657908
# --Topic number 20 coherence score: 0.4094406225738248
# --Topic number 30 coherence score: 0.4344411516916182
# --Topic number 40 coherence score: 0.4212844870544674
# --Topic number 50 coherence score: 0.42003906935361407
# --Topic number 100 coherence score: 0.3850433513994528
# --Topic number 150 coherence score: 0.35727334698329855
# --Topic number 200 coherence score: 0.3345861669446581

# %%
with open('coherences_12grams_uk_new.json','w') as json_file:
    json.dump({'coherences': coherences_12grams,
               'predicted_topics': predicted_topics_counts_12grams}, json_file)

# %%
plt.plot(topic_numbers_12grams, coherences_12grams)
plt.title('Coherence for different n_topics | 12grams model, new preprocessing | Ukrainian')
plt.xlabel('Topics number')
plt.ylabel('Coherence (c_v) score')
plt.grid()
plt.show()

# %% [markdown]
# # 1- and 2-grams with the new processing, only certain PoS
#
# Let's build a model that performs topic modelling only for the certain most important parts of speech (PoS), starting with the nouns, verbs, adjectives, and adverbs. We have such an information thanks to using the `stanza` pipeline. The motivation behind this is that the most important speech parts may store the most information about the document's idea and purpose, which is even more important in the case of the tweets.
#
# We'll later likely return to review the models based only a single PoS, like, for example, nouns. This can also be useful to detect spam in the messages, and adjectives can potentially be useful in detecting propaganda or emotionally charged documents.
#
# We'll use the POS tags as defined in the [Universal POS tags](https://universaldependencies.org/u/pos/), as opposed to the [Penn Treebank tag set](https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html).

# %%
doc = stanza_pip(all_documents_0922_uk[0])

# %%
print([word for sent in doc.sentences for word in sent.words if word.upos in [
    'NOUN','PNOUN','VERB','ADJ','ADV']])
# Out:
# [{
#   "id": 1,
#   "text": "Міноборони",
#   "lemma": "міноборон",
#   "upos": "NOUN",
#   "xpos": "Ncmpnn",
#   "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Plur",
#   "start_char": 0,
#   "end_char": 10
# }, {
#   "id": 2,
#   "text": "передало",
#   "lemma": "передати",
#   "upos": "VERB",
#   "xpos": "Vmeis-sn",
#   "feats": "Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin",
#   "start_char": 11,
#   "end_char": 19
# }, {
#   "id": 4,
#   "text": "парламенту",
#   "lemma": "парламент",
#   "upos": "NOUN",
#   "xpos": "Ncmsgn",
#   "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#   "start_char": 23,
#   "end_char": 33
# }, {
#   "id": 5,
#   "text": "пропозиції",
#   "lemma": "пропозиція",
#   "upos": "NOUN",
#   "xpos": "Ncfpan",
#   "feats": "Animacy=Inan|Case=Acc|Gender=Fem|Number=Plur",
#   "start_char": 34,
#   "end_char": 44
# }, {
#   "id": 6,
#   "text": "змін",
#   "lemma": "зміна",
#   "upos": "NOUN",
#   "xpos": "Ncfpgn",
#   "feats": "Animacy=Inan|Case=Gen|Gender=Fem|Number=Plur",
#   "start_char": 45,
#   "end_char": 49
# }, {
#   "id": 8,
#   "text": "закону",
#   "lemma": "закон",
#   "upos": "NOUN",
#   "xpos": "Ncmsgn",
#   "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#   "start_char": 53,
#   "end_char": 59
# }, {
#   "id": 10,
#   "text": "військовий",
#   "lemma": "військовий",
#   "upos": "ADJ",
#   "xpos": "Ao-msafn",
#   "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#   "start_char": 64,
#   "end_char": 74
# }, {
#   "id": 11,
#   "text": "обов’язок",
#   "lemma": "обов’язка",
#   "upos": "NOUN",
#   "xpos": "Ncmsan",
#   "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#   "start_char": 75,
#   "end_char": 84
# }, {
#   "id": 13,
#   "text": "добровільності",
#   "lemma": "добровільність",
#   "upos": "NOUN",
#   "xpos": "Ncfsgn",
#   "feats": "Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing",
#   "start_char": 90,
#   "end_char": 104
# }, {
#   "id": 14,
#   "text": "постановки",
#   "lemma": "постановка",
#   "upos": "NOUN",
#   "xpos": "Ncfsgn",
#   "feats": "Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing",
#   "start_char": 105,
#   "end_char": 115
# }, {
#   "id": 16,
#   "text": "військовий",
#   "lemma": "військовий",
#   "upos": "ADJ",
#   "xpos": "Ao-msafn",
#   "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#   "start_char": 119,
#   "end_char": 129
# }, {
#   "id": 17,
#   "text": "облік",
#   "lemma": "облік",
#   "upos": "NOUN",
#   "xpos": "Ncmsan",
#   "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing",
#   "start_char": 130,
#   "end_char": 135
# }, {
#   "id": 18,
#   "text": "жінок",
#   "lemma": "жінка",
#   "upos": "NOUN",
#   "xpos": "Ncfpgy",
#   "feats": "Animacy=Anim|Case=Gen|Gender=Fem|Number=Plur",
#   "start_char": 136,
#   "end_char": 141
# }]

# %%
print([word.lemma for sent in doc.sentences for word in sent.words if word.upos in [
    'NOUN','PNOUN','VERB','ADJ','ADV']])
# Out:
# ['міноборон', 'передати', 'парламент', 'пропозиція', 'зміна', 'закон', 'військовий', 'обов’язка', 'добровільність', 'постановка', 'військовий', 'облік', 'жінка']

# %%
class UkrainianPreprocessor_v3:
    def preprocess_documents(self, documents_list: list,
                             filter_by_pos: list = [], return_strings: bool = True,
                             verbose: int = 0):
        preprocessed_documents = []
        for i_d, doc in enumerate(documents_list):
            preprocessed_documents.append(self.preprocess(doc,
                                                          filter_by_pos=filter_by_pos,
                                                          return_string=return_strings))
            if (verbose == 1) and ((i_d == 0) or ((i_d + 1)%100 == 0)):
                print(f'--Preprocessed documents: {i_d+1}/{len(documents_list)}')
        return preprocessed_documents
    
    # Function to preprocess documents
    def preprocess(self, document, filter_by_pos: list = [], return_string: bool = True):
        # Clean the document
        document = self.remove_links_content(document)
        document = self.remove_emails(document)
        document = self.remove_multiple_space(document)
        document = self.remove_hashtags(document)
        document = self.remove_punctuation(document)
        document = self.remove_multiple_space(document)
        
        # Tokenize and lemmatize
        processed_document = stanza_pip(document.lower())
        if len(filter_by_pos) > 0:
            lemmatized_words = [word.lemma for sent in processed_document.sentences for word in sent.words if (
                word.upos in filter_by_pos)]
        else:
            lemmatized_words = [word.lemma for sent in processed_document.sentences for word in sent.words]
        # Remove stopwords and punctuations
        filtered_words = [word for word in lemmatized_words if word.isalnum() and not word in stop_words]
        if return_string:
            return ' '.join(filtered_words)
        else:
            return filtered_words
    
    def remove_links_content(self, text):
        text = re.sub(r"http\S+", "", text)
        return text
    
    def remove_emails(self, text):
        return re.sub('\S+@\S*\s?', '', text)
    
    def remove_punctuation(self, text):
        """https://stackoverflow.com/a/37221663"""
        table = str.maketrans({key: None for key in string.punctuation})
        return text.translate(table)
    
    def remove_multiple_space(self, text):
        return re.sub("\s\s+", " ", text)

    def remove_hashtags(self, text):
        old_text = text + '\n'
        new_text = text
        while len(new_text) < len(old_text):
            old_text = new_text
            new_text = re.sub('(?<=[\s\n])#\S+\s*$', '', new_text)
        return new_text

# %%
class LSAPipelineUkrainian_v3:
    def __init__(self, documents_list, tf_idf_max_df=1.0, tf_idf_min_df=1,
                 lsa_components: int = 100, svd_n_iter: int = 5,
                 n_top_words: int = 10, ngram_range: tuple = (1, 1),
                 filter_by_pos: list = [], random_state: int = -1,
                 import_preprocessed_documents: bool = False, verbose: int = 0):
        if not import_preprocessed_documents:
            self.import_documents_list = UkrainianPreprocessor_v3().preprocess_documents(documents_list,
                                                                                         filter_by_pos=filter_by_pos,
                                                                                         verbose=verbose)
        else:
            self.import_documents_list = documents_list
        self.tf_idf_max_df = tf_idf_max_df
        self.tf_idf_min_df = tf_idf_min_df
        self.lsa_components = lsa_components
        self.svd_n_iter = svd_n_iter
        self.n_top_words = n_top_words
        self.ngram_range = ngram_range
        self.random_state = random_state
        self.coherence_texts_calculated = False
        self.verbose = verbose

    def run_topics_detection(self):
        tfidf_documents = self.TF_IDF()
        if self.verbose == 1:
            print(f'--LSA topics detection: TF-IDF calculated')
        self.TruncatedSVD(tfidf_documents)
        if self.verbose == 1:
            print(f'--LSA topics detection: truncated SVD calculated')
        self.topics = self.find_topics()
        return self.topics

    def transform_documents(self, new_documents_list: list):
        return list(map(np.argmax, self.svd_model.transform(
            self.tfidf_vectorizer.transform(new_documents_list))))

    def import_ready_documents(self, documents_list, texts, dictionary, corpus):
        self.import_documents_list = documents_list
        self.texts = texts
        self.dictionary = dictionary
        self.corpus = corpus
        self.coherence_texts_calculated = True

    def TF_IDF(self):
        self.tfidf_vectorizer = TfidfVectorizer(max_df=self.tf_idf_max_df,
                                                min_df=self.tf_idf_min_df,
                                                ngram_range=self.ngram_range,
                                                stop_words=stop_words)
        return self.tfidf_vectorizer.fit_transform(self.import_documents_list)
        # tfidf_feature_names = self.tfidf_vectorizer.get_feature_names_out()
    
    def TruncatedSVD(self, tfidf_documents):
        if self.random_state != -1:
            self.svd_model = TruncatedSVD(n_components=self.lsa_components,
                                 n_iter=self.svd_n_iter, random_state=self.random_state)
        else:
            self.svd_model = TruncatedSVD(n_components=self.lsa_components,
                                 n_iter=self.svd_n_iter)
        self.svd_model.fit_transform(tfidf_documents)

    def find_topics(self):
        # Extract the top words for each topic
        topics = []
        tfidf_feature_names = self.tfidf_vectorizer.get_feature_names_out()
        for topic_idx, topic in enumerate(self.svd_model.components_):
            top_features_ind = topic.argsort()[:-self.n_top_words - 1:-1]
            top_features = [tfidf_feature_names[i] for i in top_features_ind]
            topics.append(top_features)
        return topics

    def calculate_coherence_score(self, recalculate_texts: bool = False, verbose: int = 0):
        if not self.coherence_texts_calculated or recalculate_texts:
            self.calculate_coherence_texts(verbose=verbose)
        # Calculate the coherence score using Gensim
        coherence_model = CoherenceModel(topics=self.topics,
                                         texts=self.texts,
                                         dictionary=self.dictionary,
                                         coherence='c_v')
        if verbose == 1:
            print(f'--Calculating the coherence score')
        self.coherence_score = coherence_model.get_coherence()
        return self.coherence_score

    def calculate_coherence_texts(self, verbose: int = 0):
        # Convert the list of top words into a list of lists of words
        tfidf_feature_names = set(self.tfidf_vectorizer.get_feature_names_out())
        if verbose == 1:
            print(f'--Starting forming the texts')
        self.texts = [[word for word in doc.lower().split() if (
            word in tfidf_feature_names)] for doc in self.import_documents_list]
        # Create a Gensim dictionary
        if verbose == 1:
            print(f'--Creating the Gensim dectionary')
        self.dictionary = Dictionary(self.texts)
        # Convert the dictionary and the corpus
        if verbose == 1:
            print(f'--Converting to the corpus')
        self.corpus = [self.dictionary.doc2bow(text) for text in self.texts]
        self.coherence_texts_calculated = True

# %%
LSAPipeline = LSAPipelineUkrainian_v3(all_documents_0922_uk, tf_idf_max_df=0.9, tf_idf_min_df=4,
                                 lsa_components=5, svd_n_iter=5,
                                 n_top_words=10, ngram_range=(1,2),
                                 filter_by_pos=['NOUN','PNOUN','VERB','ADJ','ADV'],
                                 random_state=47, verbose=1)
topics = LSAPipeline.run_topics_detection()
# Out:
# --Preprocessed documents: 1/98087
# --Preprocessed documents: 100/98087
# --Preprocessed documents: 200/98087
# --Preprocessed documents: 300/98087
# --Preprocessed documents: 400/98087
# --Preprocessed documents: 500/98087
# --Preprocessed documents: 600/98087
# --Preprocessed documents: 700/98087
# --Preprocessed documents: 800/98087
# --Preprocessed documents: 900/98087
# --Preprocessed documents: 1000/98087
# --Preprocessed documents: 1100/98087
# --Preprocessed documents: 1200/98087
# --Preprocessed documents: 1300/98087
# --Preprocessed documents: 1400/98087
# --Preprocessed documents: 1500/98087
# --Preprocessed documents: 1600/98087
# --Preprocessed documents: 1700/98087
# --Preprocessed documents: 1800/98087
# --Preprocessed documents: 1900/98087
# --Preprocessed documents: 2000/98087
# --Preprocessed documents: 2100/98087
# --Preprocessed documents: 2200/98087
# --Preprocessed documents: 2300/98087
# --Preprocessed documents: 2400/98087
# --Preprocessed documents: 2500/98087
# --Preprocessed documents: 2600/98087
# --Preprocessed documents: 2700/98087
# --Preprocessed documents: 2800/98087
# --Preprocessed documents: 2900/98087
# --Preprocessed documents: 3000/98087
# --Preprocessed documents: 3100/98087
# --Preprocessed documents: 3200/98087
# --Preprocessed documents: 3300/98087
# --Preprocessed documents: 3400/98087
# --Preprocessed documents: 3500/98087
# --Preprocessed documents: 3600/98087
# --Preprocessed documents: 3700/98087
# --Preprocessed documents: 3800/98087
# --Preprocessed documents: 3900/98087
# --Preprocessed documents: 4000/98087
# --Preprocessed documents: 4100/98087
# --Preprocessed documents: 4200/98087
# --Preprocessed documents: 4300/98087
# --Preprocessed documents: 4400/98087
# --Preprocessed documents: 4500/98087
# --Preprocessed documents: 4600/98087
# --Preprocessed documents: 4700/98087
# --Preprocessed documents: 4800/98087
# --Preprocessed documents: 4900/98087
# --Preprocessed documents: 5000/98087
# --Preprocessed documents: 5100/98087
# --Preprocessed documents: 5200/98087
# --Preprocessed documents: 5300/98087
# --Preprocessed documents: 5400/98087
# --Preprocessed documents: 5500/98087
# --Preprocessed documents: 5600/98087
# --Preprocessed documents: 5700/98087
# --Preprocessed documents: 5800/98087
# --Preprocessed documents: 5900/98087
# --Preprocessed documents: 6000/98087
# --Preprocessed documents: 6100/98087
# --Preprocessed documents: 6200/98087
# --Preprocessed documents: 6300/98087
# --Preprocessed documents: 6400/98087
# --Preprocessed documents: 6500/98087
# --Preprocessed documents: 6600/98087
# --Preprocessed documents: 6700/98087
# --Preprocessed documents: 6800/98087
# --Preprocessed documents: 6900/98087
# --Preprocessed documents: 7000/98087
# --Preprocessed documents: 7100/98087
# --Preprocessed documents: 7200/98087
# --Preprocessed documents: 7300/98087
# --Preprocessed documents: 7400/98087
# --Preprocessed documents: 7500/98087
# --Preprocessed documents: 7600/98087
# --Preprocessed documents: 7700/98087
# --Preprocessed documents: 7800/98087
# --Preprocessed documents: 7900/98087
# --Preprocessed documents: 8000/98087
# --Preprocessed documents: 8100/98087
# --Preprocessed documents: 8200/98087
# --Preprocessed documents: 8300/98087
# --Preprocessed documents: 8400/98087
# --Preprocessed documents: 8500/98087
# --Preprocessed documents: 8600/98087
# --Preprocessed documents: 8700/98087
# --Preprocessed documents: 8800/98087
# --Preprocessed documents: 8900/98087
# --Preprocessed documents: 9000/98087
# --Preprocessed documents: 9100/98087
# --Preprocessed documents: 9200/98087
# --Preprocessed documents: 9300/98087
# --Preprocessed documents: 9400/98087
# --Preprocessed documents: 9500/98087
# --Preprocessed documents: 9600/98087
# --Preprocessed documents: 9700/98087
# --Preprocessed documents: 9800/98087
# --Preprocessed documents: 9900/98087
# --Preprocessed documents: 10000/98087
# --Preprocessed documents: 10100/98087
# --Preprocessed documents: 10200/98087
# --Preprocessed documents: 10300/98087
# --Preprocessed documents: 10400/98087
# --Preprocessed documents: 10500/98087
# --Preprocessed documents: 10600/98087
# --Preprocessed documents: 10700/98087
# --Preprocessed documents: 10800/98087
# --Preprocessed documents: 10900/98087
# --Preprocessed documents: 11000/98087
# --Preprocessed documents: 11100/98087
# --Preprocessed documents: 11200/98087
# --Preprocessed documents: 11300/98087
# --Preprocessed documents: 11400/98087
# --Preprocessed documents: 11500/98087
# --Preprocessed documents: 11600/98087
# --Preprocessed documents: 11700/98087
# --Preprocessed documents: 11800/98087
# --Preprocessed documents: 11900/98087
# --Preprocessed documents: 12000/98087
# --Preprocessed documents: 12100/98087
# --Preprocessed documents: 12200/98087
# --Preprocessed documents: 12300/98087
# --Preprocessed documents: 12400/98087
# --Preprocessed documents: 12500/98087
# --Preprocessed documents: 12600/98087
# --Preprocessed documents: 12700/98087
# --Preprocessed documents: 12800/98087
# --Preprocessed documents: 12900/98087
# --Preprocessed documents: 13000/98087
# --Preprocessed documents: 13100/98087
# --Preprocessed documents: 13200/98087
# --Preprocessed documents: 13300/98087
# --Preprocessed documents: 13400/98087
# --Preprocessed documents: 13500/98087
# --Preprocessed documents: 13600/98087
# --Preprocessed documents: 13700/98087
# --Preprocessed documents: 13800/98087
# --Preprocessed documents: 13900/98087
# --Preprocessed documents: 14000/98087
# --Preprocessed documents: 14100/98087
# --Preprocessed documents: 14200/98087
# --Preprocessed documents: 14300/98087
# --Preprocessed documents: 14400/98087
# --Preprocessed documents: 14500/98087
# --Preprocessed documents: 14600/98087
# --Preprocessed documents: 14700/98087
# --Preprocessed documents: 14800/98087
# --Preprocessed documents: 14900/98087
# --Preprocessed documents: 15000/98087
# --Preprocessed documents: 15100/98087
# --Preprocessed documents: 15200/98087
# --Preprocessed documents: 15300/98087
# --Preprocessed documents: 15400/98087
# --Preprocessed documents: 15500/98087
# --Preprocessed documents: 15600/98087
# --Preprocessed documents: 92000/98087
# --Preprocessed documents: 92100/98087
# --Preprocessed documents: 92200/98087
# --Preprocessed documents: 92300/98087
# --Preprocessed documents: 92400/98087
# --Preprocessed documents: 92500/98087
# --Preprocessed documents: 92600/98087
# --Preprocessed documents: 92700/98087
# --Preprocessed documents: 92800/98087
# --Preprocessed documents: 92900/98087
# --Preprocessed documents: 93000/98087
# --Preprocessed documents: 93100/98087
# --Preprocessed documents: 93200/98087
# --Preprocessed documents: 93300/98087
# --Preprocessed documents: 93400/98087
# --Preprocessed documents: 93500/98087
# --Preprocessed documents: 93600/98087
# --Preprocessed documents: 93700/98087
# --Preprocessed documents: 93800/98087
# --Preprocessed documents: 93900/98087
# --Preprocessed documents: 94000/98087
# --Preprocessed documents: 94100/98087
# --Preprocessed documents: 94200/98087
# --Preprocessed documents: 94300/98087
# --Preprocessed documents: 94400/98087
# --Preprocessed documents: 94500/98087
# --Preprocessed documents: 94600/98087
# --Preprocessed documents: 94700/98087
# --Preprocessed documents: 94800/98087
# --Preprocessed documents: 94900/98087
# --Preprocessed documents: 95000/98087
# --Preprocessed documents: 95100/98087
# --Preprocessed documents: 95200/98087
# --Preprocessed documents: 95300/98087
# --Preprocessed documents: 95400/98087
# --Preprocessed documents: 95500/98087
# --Preprocessed documents: 95600/98087
# --Preprocessed documents: 95700/98087
# --Preprocessed documents: 95800/98087
# --Preprocessed documents: 95900/98087
# --Preprocessed documents: 96000/98087
# --Preprocessed documents: 96100/98087
# --Preprocessed documents: 96200/98087
# --Preprocessed documents: 96300/98087
# --Preprocessed documents: 96400/98087
# --Preprocessed documents: 96500/98087
# --Preprocessed documents: 96600/98087
# --Preprocessed documents: 96700/98087
# --Preprocessed documents: 96800/98087
# --Preprocessed documents: 96900/98087
# --Preprocessed documents: 97000/98087
# --Preprocessed documents: 97100/98087
# --Preprocessed documents: 97200/98087
# --Preprocessed documents: 97300/98087
# --Preprocessed documents: 97400/98087
# --Preprocessed documents: 97500/98087
# --Preprocessed documents: 97600/98087
# --Preprocessed documents: 97700/98087
# --Preprocessed documents: 97800/98087
# --Preprocessed documents: 97900/98087
# --Preprocessed documents: 98000/98087
# --LSA topics detection: TF-IDF calculated
# --LSA topics detection: truncated SVD calculated

# %%
with open('preprocessed_documents_092022_uk_new_pos.json','w') as json_file:
    json.dump({'preprocessed_documents': LSAPipeline.import_documents_list}, json_file)

# %%
with open('preprocessed_documents_092022_uk_new_pos.json','r') as json_file:
    preprocessed_documents_pos = json.load(json_file)['preprocessed_documents']

# %%
preprocessed_documents_pos[0]
# Out:
# 'міноборони передати парламент пропозиція зміна закон військовий добровільність постановка військовий облік жінка'

# %%
topics
# Out:
# [['дякувати',
#   'приємно',
#   'дякувати підтримка',
#   'підтримка',
#   'пане',
#   'зса',
#   'слава',
#   'дякувати зса',
#   'дякувати пане',
#   'пані'],
#  ['іти ебать',
#   'ебать путін',
#   'ебать',
#   'іти',
#   'путін',
#   'війна',
#   'росія',
#   'росіянин',
#   'нахувати',
#   'іти нахувати'],
#  ['слава',
#   'герой',
#   'зса',
#   'слава герой',
#   'слава зса',
#   'герой слава',
#   'слава слава',
#   'воїн',
#   'слава воїн',
#   'смерть'],
#  ['війна',
#   'війна анімація',
#   'анімація',
#   'знати',
#   'думати',
#   'робити',
#   'росія',
#   'бачити',
#   'російський',
#   'немати'],
#  ['підписатися',
#   'соловїна',
#   'соловїна підписатися',
#   'підписатися адвокат',
#   'адвокат',
#   'чекати',
#   'казати',
#   'зса',
#   'писати',
#   'публікувати світлина']]

# %%
tfidf_feature_names = set(LSAPipeline.tfidf_vectorizer.get_feature_names_out())
preprocessed_documents = LSAPipeline.import_documents_list

# %%
# Convert the list of ngrams into a list of lists of words
texts_v6 = [[word for word in doc.lower().split() if (
    word in tfidf_feature_names)] + tokenize_ngrams(doc, 2) for doc in preprocessed_documents]

# Create a Gensim dictionary
dictionary_v6 = Dictionary(texts_v6)

# Convert the dictionary and the corpus
corpus_v6 = [dictionary_v4.doc2bow(text) for text in texts_v6]

# %%
# Calculate the coherence score using Gensim
coherence_model = CoherenceModel(topics=topics,
                                 texts=texts_v6,
                                 dictionary=dictionary_v6,
                                 corpus=corpus_v6,
                                 coherence='c_v')
coherence_score = coherence_model.get_coherence()

print('Coherence Score:', coherence_score)
# Out:
# Coherence Score: 0.39171220461669504

# %% [markdown]
# Only for the nouns and verbs:

# %%
LSAPipeline = LSAPipelineUkrainian_v3(all_documents_0922_uk, tf_idf_max_df=0.9, tf_idf_min_df=4,
                                 lsa_components=5, svd_n_iter=5,
                                 n_top_words=10, ngram_range=(1,2),
                                 filter_by_pos=['NOUN','PNOUN','VERB'],
                                 random_state=47, verbose=1)
topics = LSAPipeline.run_topics_detection()
# Out:
# --Preprocessed documents: 1/98087
# --Preprocessed documents: 100/98087
# --Preprocessed documents: 200/98087
# --Preprocessed documents: 300/98087
# --Preprocessed documents: 400/98087
# --Preprocessed documents: 500/98087
# --Preprocessed documents: 600/98087
# --Preprocessed documents: 700/98087
# --Preprocessed documents: 800/98087
# --Preprocessed documents: 900/98087
# --Preprocessed documents: 1000/98087
# --Preprocessed documents: 1100/98087
# --Preprocessed documents: 1200/98087
# --Preprocessed documents: 1300/98087
# --Preprocessed documents: 1400/98087
# --Preprocessed documents: 1500/98087
# --Preprocessed documents: 1600/98087
# --Preprocessed documents: 1700/98087
# --Preprocessed documents: 1800/98087
# --Preprocessed documents: 1900/98087
# --Preprocessed documents: 2000/98087
# --Preprocessed documents: 2100/98087
# --Preprocessed documents: 2200/98087
# --Preprocessed documents: 2300/98087
# --Preprocessed documents: 2400/98087
# --Preprocessed documents: 2500/98087
# --Preprocessed documents: 2600/98087
# --Preprocessed documents: 2700/98087
# --Preprocessed documents: 2800/98087
# --Preprocessed documents: 2900/98087
# --Preprocessed documents: 3000/98087
# --Preprocessed documents: 3100/98087
# --Preprocessed documents: 3200/98087
# --Preprocessed documents: 3300/98087
# --Preprocessed documents: 3400/98087
# --Preprocessed documents: 3500/98087
# --Preprocessed documents: 3600/98087
# --Preprocessed documents: 3700/98087
# --Preprocessed documents: 3800/98087
# --Preprocessed documents: 3900/98087
# --Preprocessed documents: 4000/98087
# --Preprocessed documents: 4100/98087
# --Preprocessed documents: 4200/98087
# --Preprocessed documents: 4300/98087
# --Preprocessed documents: 4400/98087
# --Preprocessed documents: 4500/98087
# --Preprocessed documents: 4600/98087
# --Preprocessed documents: 4700/98087
# --Preprocessed documents: 4800/98087
# --Preprocessed documents: 4900/98087
# --Preprocessed documents: 5000/98087
# --Preprocessed documents: 5100/98087
# --Preprocessed documents: 5200/98087
# --Preprocessed documents: 5300/98087
# --Preprocessed documents: 5400/98087
# --Preprocessed documents: 5500/98087
# --Preprocessed documents: 5600/98087
# --Preprocessed documents: 5700/98087
# --Preprocessed documents: 5800/98087
# --Preprocessed documents: 5900/98087
# --Preprocessed documents: 6000/98087
# --Preprocessed documents: 6100/98087
# --Preprocessed documents: 6200/98087
# --Preprocessed documents: 6300/98087
# --Preprocessed documents: 6400/98087
# --Preprocessed documents: 6500/98087
# --Preprocessed documents: 6600/98087
# --Preprocessed documents: 6700/98087
# --Preprocessed documents: 6800/98087
# --Preprocessed documents: 6900/98087
# --Preprocessed documents: 7000/98087
# --Preprocessed documents: 7100/98087
# --Preprocessed documents: 7200/98087
# --Preprocessed documents: 7300/98087
# --Preprocessed documents: 7400/98087
# --Preprocessed documents: 7500/98087
# --Preprocessed documents: 7600/98087
# --Preprocessed documents: 7700/98087
# --Preprocessed documents: 7800/98087
# --Preprocessed documents: 7900/98087
# --Preprocessed documents: 8000/98087
# --Preprocessed documents: 8100/98087
# --Preprocessed documents: 8200/98087
# --Preprocessed documents: 8300/98087
# --Preprocessed documents: 8400/98087
# --Preprocessed documents: 8500/98087
# --Preprocessed documents: 8600/98087
# --Preprocessed documents: 8700/98087
# --Preprocessed documents: 8800/98087
# --Preprocessed documents: 8900/98087
# --Preprocessed documents: 9000/98087
# --Preprocessed documents: 9100/98087
# --Preprocessed documents: 9200/98087
# --Preprocessed documents: 9300/98087
# --Preprocessed documents: 9400/98087
# --Preprocessed documents: 9500/98087
# --Preprocessed documents: 9600/98087
# --Preprocessed documents: 9700/98087
# --Preprocessed documents: 9800/98087
# --Preprocessed documents: 9900/98087
# --Preprocessed documents: 10000/98087
# --Preprocessed documents: 10100/98087
# --Preprocessed documents: 10200/98087
# --Preprocessed documents: 10300/98087
# --Preprocessed documents: 10400/98087
# --Preprocessed documents: 10500/98087
# --Preprocessed documents: 10600/98087
# --Preprocessed documents: 10700/98087
# --Preprocessed documents: 10800/98087
# --Preprocessed documents: 10900/98087
# --Preprocessed documents: 11000/98087
# --Preprocessed documents: 11100/98087
# --Preprocessed documents: 11200/98087
# --Preprocessed documents: 11300/98087
# --Preprocessed documents: 11400/98087
# --Preprocessed documents: 11500/98087
# --Preprocessed documents: 11600/98087
# --Preprocessed documents: 11700/98087
# --Preprocessed documents: 11800/98087
# --Preprocessed documents: 11900/98087
# --Preprocessed documents: 12000/98087
# --Preprocessed documents: 12100/98087
# --Preprocessed documents: 12200/98087
# --Preprocessed documents: 12300/98087
# --Preprocessed documents: 12400/98087
# --Preprocessed documents: 12500/98087
# --Preprocessed documents: 12600/98087
# --Preprocessed documents: 12700/98087
# --Preprocessed documents: 97700/98087
# --Preprocessed documents: 97800/98087
# --Preprocessed documents: 97900/98087
# --Preprocessed documents: 98000/98087
# --LSA topics detection: TF-IDF calculated
# --LSA topics detection: truncated SVD calculated

# %%
with open('preprocessed_documents_092022_uk_new_pos_noun_verb.json','w') as json_file:
    json.dump({'preprocessed_documents': LSAPipeline.import_documents_list}, json_file)

# %%
topics
# Out:
# [['дякувати',
#   'підтримка',
#   'дякувати підтримка',
#   'зса',
#   'пане',
#   'дякувати зса',
#   'слава',
#   'пані',
#   'дякувати пане',
#   'знати'],
#  ['іти',
#   'іти ебать',
#   'ебать путін',
#   'ебать',
#   'путін',
#   'війна',
#   'росія',
#   'росіянин',
#   'мобілізація',
#   'нахувати'],
#  ['слава',
#   'герой',
#   'зса',
#   'слава герой',
#   'слава зса',
#   'герой слава',
#   'слава слава',
#   'воїн',
#   'слава воїн',
#   'перемога'],
#  ['знати',
#   'війна',
#   'анімація',
#   'війна анімація',
#   'робити',
#   'думати',
#   'немати',
#   'бачити',
#   'місто',
#   'росія'],
#  ['війна',
#   'війна анімація',
#   'анімація',
#   'опубликувати',
#   'росія',
#   'русня',
#   'чекати',
#   'місто',
#   'початок',
#   'вітати']]

# %%
tfidf_feature_names = set(LSAPipeline.tfidf_vectorizer.get_feature_names_out())
preprocessed_documents = LSAPipeline.import_documents_list

# %%
# Convert the list of ngrams into a list of lists of words
texts_v7 = [[word for word in doc.lower().split() if (
    word in tfidf_feature_names)] + tokenize_ngrams(doc, 2) for doc in preprocessed_documents]

# Create a Gensim dictionary
dictionary_v7 = Dictionary(texts_v7)

# Convert the dictionary and the corpus
corpus_v7 = [dictionary_v4.doc2bow(text) for text in texts_v7]

# %%
# Calculate the coherence score using Gensim
coherence_model = CoherenceModel(topics=topics,
                                 texts=texts_v7,
                                 dictionary=dictionary_v7,
                                 corpus=corpus_v7,
                                 coherence='c_v')
coherence_score = coherence_model.get_coherence()

print('Coherence Score:', coherence_score)
# Out:
# Coherence Score: 0.4021543022254982

# %% [markdown]
# ## 1- and 2-grams with the new processing, only certain PoS: optimal topics number
#
# Model that uses both 1- and 2-grams with the new preprocessing only for the certain most important parts of speech (PoS) for the different topics numbers for the data for September 2022 in Ukrainian language.

# %%
topic_numbers_12grams = list(range(2,15)) + [20,30,40,50,100,150,200]
coherences_12grams = []
predicted_topics_counts_12grams = []
for topic_number in topic_numbers_12grams:
    LSAPipeline = LSAPipelineUkrainian_v3(preprocessed_documents_pos, tf_idf_max_df=0.9, tf_idf_min_df=4,
                                 lsa_components=topic_number, svd_n_iter=5,
                                 n_top_words=10, ngram_range=(1,2),
                                 filter_by_pos=['NOUN','PNOUN','VERB','ADJ','ADV'],
                                 import_preprocessed_documents=True, random_state=47)
    topics_12grams = LSAPipeline.run_topics_detection()
    tfidf_feature_names = set(LSAPipeline.tfidf_vectorizer.get_feature_names_out())
    # Calculate the coherence score using Gensim
    coherence_model = CoherenceModel(topics=topics_12grams,
                                     texts=texts_v4,
                                     dictionary=dictionary_v4,
                                     corpus=corpus_v4,
                                     coherence='c_v')
    coherence_score = coherence_model.get_coherence()
    predicted_topics = LSAPipeline.transform_documents(LSAPipeline.import_documents_list)
    predicted_topics_count = [predicted_topics.count(x) for x in np.sort(np.unique(predicted_topics))]
    
    print(f'--Topic number {topic_number} coherence score: {coherence_score}')
    coherences_12grams.append(coherence_score)
    predicted_topics_counts_12grams.append(predicted_topics_count)
# Out:
# --Topic number 2 coherence score: 0.2069006109716433
# --Topic number 3 coherence score: 0.34920666477070245
# --Topic number 4 coherence score: 0.31904030059744237
# --Topic number 5 coherence score: 0.30639945371965316
# --Topic number 6 coherence score: 0.3044469457432906
# --Topic number 7 coherence score: 0.32302346461489445
# --Topic number 8 coherence score: 0.2875231238684669
# --Topic number 9 coherence score: 0.2903439921190726
# --Topic number 10 coherence score: 0.3000541144999219
# --Topic number 11 coherence score: 0.29656198080349133
# --Topic number 12 coherence score: 0.2947390737329594
# --Topic number 13 coherence score: 0.32078782632253144
# --Topic number 14 coherence score: 0.301363094929168
# --Topic number 20 coherence score: 0.3251487444051565
# --Topic number 30 coherence score: 0.3190739538285825
# --Topic number 40 coherence score: 0.30942640394185367
# --Topic number 50 coherence score: 0.32207147626074745
# --Topic number 100 coherence score: 0.34796372002997566
# --Topic number 150 coherence score: 0.3611665722750889
# --Topic number 200 coherence score: 0.38102802944672143

# %%
topics_12grams
# Out:
# [['дякувати',
#   'приємно',
#   'дякувати підтримка',
#   'підтримка',
#   'пане',
#   'зса',
#   'слава',
#   'дякувати зса',
#   'дякувати пане',
#   'пані'],
#  ['ебать путін',
#   'іти ебать',
#   'ебать',
#   'іти',
#   'путін',
#   'війна',
#   'росія',
#   'росіянин',
#   'нахувати',
#   'іти нахувати'],
#  ['слава',
#   'герой',
#   'зса',
#   'слава герой',
#   'слава зса',
#   'герой слава',
#   'слава слава',
#   'воїн',
#   'слава воїн',
#   'смерть'],
#  ['війна',
#   'війна анімація',
#   'анімація',
#   'знати',
#   'робити',
#   'росія',
#   'немати',
#   'російський',
#   'думати',
#   'зса'],
#  ['підписатися',
#   'соловїна',
#   'підписатися адвокат',
#   'соловїна підписатися',
#   'адвокат',
#   'знати',
#   'робити',
#   'думати',
#   'немати',
#   'бачити'],
#  ['знати',
#   'робити',
#   'думати',
#   'немати',
#   'бачити',
#   'казати',
#   'розуміти',
#   'зробити',
#   'зса',
#   'російський'],
#  ['знати',
#   'війна анімація',
#   'анімація',
#   'слава',
#   'війна',
#   'знати знати',
#   'іти ебать',
#   'ебать путін',
#   'ебать',
#   'дякувати'],
#  ['опубликувати',
#   'знати',
#   'опубликувати фото',
#   'фото',
#   'війна анімація',
#   'анімація',
#   'слава',
#   'війна',
#   'знати знати',
#   'іти ебать'],
#  ['світлина',
#   'публікувати світлина',
#   'публікувати',
#   'світлина живий',
#   'живий парафія',
#   'парафія',
#   'живий',
#   'заповідник',
#   'світлина карпатський',
#   'карпатський біосферний'],
#  ['зса',
#   'допомогти',
#   'орок',
#   'лязти',
#   'тіло лязти',
#   'ґрунт',
#   'ґрунт допомогти',
#   'лязти ґрунт',
#   'орок тіло',
#   'допомогти зса'],
#  ['думати',
#   'бачити',
#   'знати',
#   'дивитися',
#   'розуміти',
#   'піти',
#   'писати',
#   'написати',
#   'допомогти',
#   'подобатися'],
#  ['робити',
#   'думати',
#   'допомогти',
#   'тіло лязти',
#   'лязти',
#   'лязти ґрунт',
#   'ґрунт допомогти',
#   'орок тіло',
#   'ґрунт',
#   'допомогти зса'],
#  ['бачити',
#   'робити',
#   'допомогти',
#   'орок',
#   'лязти',
#   'тіло лязти',
#   'ґрунт допомогти',
#   'лязти ґрунт',
#   'орок тіло',
#   'ґрунт'],
#  ['немати',
#   'бачити',
#   'думати',
#   'допомогти',
#   'ґрунт',
#   'лязти',
#   'тіло лязти',
#   'орок тіло',
#   'лязти ґрунт',
#   'ґрунт допомогти'],
#  ['розуміти',
#   'казати',
#   'працювати',
#   'писати',
#   'жити',
#   'любити',
#   'взагалі',
#   'питання',
#   'допомогти',
#   'русня'],
#  ['чекати',
#   'розуміти',
#   'вітати',
#   'дивитися',
#   'гарний',
#   'ранок',
#   'зробити',
#   'вірити',
#   'триматися',
#   'допомогти'],
#  ['зробити',
#   'казати',
#   'гарний',
#   'піти',
#   'допомогти',
#   'дивитися',
#   'любити',
#   'лязти',
#   'ґрунт',
#   'тіло лязти'],
#  ['вітати',
#   'любити',
#   'гарний',
#   'місто',
#   'народження',
#   'цікаво',
#   'вітати народження',
#   'герой',
#   'пані',
#   'пане'],
#  ['казати',
#   'гарний',
#   'піти',
#   'любити',
#   'цікаво',
#   'писати',
#   'жити',
#   'русня',
#   'подобатися',
#   'дивитися'],
#  ['гарний',
#   'новий',
#   'новина',
#   'любити',
#   'ранок',
#   'добрий',
#   'піти',
#   'гарний новина',
#   'фото',
#   'добрий ранок'],
#  ['новий',
#   'відео',
#   'новий відео',
#   'врятований',
#   'маріупол новий',
#   'відео течія',
#   'врятований маріупол',
#   'течія',
#   'маріупол',
#   'піти'],
#  ['піти',
#   'любити',
#   'русня',
#   'працювати',
#   'цікаво',
#   'писати',
#   'дивитися',
#   'жити',
#   'нахувати',
#   'робота'],
#  ['любити',
#   'русня',
#   'писати',
#   'дивитися',
#   'жити',
#   'цікаво',
#   'працювати',
#   'українець',
#   'місто',
#   'подобатися'],
#  ['русня',
#   'писати',
#   'цікаво',
#   'гарний',
#   'добрий',
#   'ранок',
#   'йобаний',
#   'бити',
#   'йобаний русня',
#   'українець'],
#  ['писати',
#   'цікаво',
#   'працювати',
#   'написати',
#   'фото',
#   'питання',
#   'твіт',
#   'подобатися',
#   'робота',
#   'слово'],
#  ['цікаво',
#   'працювати',
#   'дивитися',
#   'жити',
#   'робота',
#   'стати',
#   'добрий',
#   'ранок',
#   'зрозуміти',
#   'росія'],
#  ['працювати',
#   'добрий',
#   'ранок',
#   'добрий ранок',
#   'робота',
#   'місто',
#   'вечір',
#   'зса',
#   'жити',
#   'добрий вечір'],
#  ['добрий',
#   'ранок',
#   'добрий ранок',
#   'вечір',
#   'зса',
#   'цікаво',
#   'новина',
#   'добрий вечір',
#   'любити',
#   'перемогти'],
#  ['місто',
#   'жити',
#   'росіянин',
#   'росія',
#   'дивитися',
#   'українець',
#   'добрий',
#   'країна',
#   'ранок',
#   'герой'],
#  ['місто',
#   'цікаво',
#   'русня',
#   'фото',
#   'область',
#   'казати',
#   'рідний',
#   'розуміти',
#   'анімація',
#   'війна анімація'],
#  ['дивитися',
#   'фото',
#   'подобатися',
#   'зса',
#   'новина',
#   'російський',
#   'фільм',
#   'чоловік',
#   'знайти',
#   'вийти'],
#  ['жити',
#   'зса',
#   'бог',
#   'новина',
#   'робота',
#   'подобатися',
#   'слава зса',
#   'генштаб',
#   'служба',
#   'служба новина'],
#  ['фото',
#   'український',
#   'російський',
#   'жити',
#   'допомогти',
#   'добрий',
#   'знайти',
#   'тіло',
#   'орок',
#   'ранок'],
#  ['фото',
#   'зса',
#   'подобатися',
#   'новина',
#   'бог',
#   'українець',
#   'росіянин',
#   'робота',
#   'знайти',
#   'питання'],
#  ['подобатися',
#   'робота',
#   'питання',
#   'український',
#   'йти',
#   'зрозуміти',
#   'взагалі',
#   'дитина',
#   'знайти',
#   'шукати'],
#  ['українець',
#   'подобатися',
#   'росіянин',
#   'жити',
#   'зса',
#   'фото',
#   'працювати',
#   'російський',
#   'дивитися',
#   'відео'],
#  ['українець',
#   'бог',
#   'робота',
#   'український',
#   'знайти',
#   'дати',
#   'зрозуміти',
#   'брати',
#   'питання',
#   'шукати'],
#  ['робота',
#   'питання',
#   'знайти',
#   'шукати',
#   'росіянин',
#   'жити',
#   'зса',
#   'йти',
#   'дивитися',
#   'українець'],
#  ['новина',
#   'герой',
#   'слава герой',
#   'служба',
#   'служба новина',
#   'черкаський служба',
#   'черкаський',
#   'дитина',
#   'герой слава',
#   'втрата'],
#  ['питання',
#   'зрозуміти',
#   'написати',
#   'зса',
#   'відповідь',
#   'шукати',
#   'знайти',
#   'взагалі',
#   'слово',
#   'український'],
#  ['росіянин',
#   'російський',
#   'дитина',
#   'бог',
#   'бити',
#   'зрозуміти',
#   'область',
#   'новина',
#   'відео',
#   'окупант'],
#  ['український',
#   'росіянин',
#   'зрозуміти',
#   'зса',
#   'слово',
#   'йти',
#   'дитина',
#   'написати',
#   'новина',
#   'стати'],
#  ['зрозуміти',
#   'російський',
#   'знайти',
#   'написати',
#   'слово',
#   'вийти',
#   'точно',
#   'взагалі',
#   'ізюм',
#   'забути'],
#  ['йти',
#   'герой',
#   'вийти',
#   'написати',
#   'зса',
#   'дитина',
#   'слово',
#   'слава герой',
#   'знайти',
#   'давати'],
#  ['йти',
#   'дитина',
#   'новина',
#   'слава',
#   'написати',
#   'російський',
#   'українець',
#   'новий',
#   'взагалі',
#   'бити'],
#  ['слово',
#   'написати',
#   'знайти',
#   'вийти',
#   'правда',
#   'слава',
#   'твіт',
#   'немати слово',
#   'ізюм',
#   'новина'],
#  ['знайти',
#   'дитина',
#   'ізюм',
#   'шукати',
#   'чоловік',
#   'відео',
#   'місце',
#   'стати',
#   'жінка',
#   'кіт'],
#  ['вийти',
#   'відео',
#   'новина',
#   'український',
#   'взагалі',
#   'бог',
#   'зрозуміти',
#   'стати',
#   'бити',
#   'немати'],
#  ['написати',
#   'бити',
#   'твіт',
#   'хлопець',
#   'прийти',
#   'герой',
#   'росія',
#   'робота',
#   'немати',
#   'український'],
#  ['дитина',
#   'написати',
#   'бити',
#   'робота',
#   'взагалі',
#   'чоловік',
#   'зса',
#   'стати',
#   'відео',
#   'зрозуміти'],
#  ['відео',
#   'маріупол',
#   'врятований',
#   'новий відео',
#   'врятований маріупол',
#   'маріупол новий',
#   'відео течія',
#   'течія',
#   'слово',
#   'йти'],
#  ['бити',
#   'здаватися',
#   'знайти',
#   'сука',
#   'взагалі',
#   'країна',
#   'зса',
#   'давати',
#   'нахувати',
#   'російський'],
#  ['область',
#   'росія',
#   'харківський',
#   'харківський область',
#   'бити',
#   'окупант',
#   'ізюм',
#   'українець',
#   'написати',
#   'новий'],
#  ['точно',
#   'стати',
#   'здаватися',
#   'взагалі',
#   'область',
#   'давати',
#   'десь',
#   'останній',
#   'забути',
#   'ізюм'],
#  ['точно',
#   'російський',
#   'забути',
#   'росія',
#   'бити',
#   'дитина',
#   'зса',
#   'знайти',
#   'росіянин',
#   'герой'],
#  ['взагалі',
#   'країна',
#   'область',
#   'точно',
#   'терорист',
#   'новина',
#   'країна терорист',
#   'анімація',
#   'війна анімація',
#   'харківський'],
#  ['давати',
#   'країна',
#   'світ',
#   'область',
#   'ізюм',
#   'перемога',
#   'харківський',
#   'втрата',
#   'бойовий',
#   'противник'],
#  ['ізюм',
#   'стати',
#   'країна',
#   'новина',
#   'точно',
#   'анімація',
#   'війна анімація',
#   'шукати',
#   'йти',
#   'терорист'],
#  ['шукати',
#   'країна',
#   'стати',
#   'область',
#   'слово',
#   'відео',
#   'здаватися',
#   'окупант',
#   'харківський',
#   'харківський область'],
#  ['стати',
#   'війна',
#   'втрата',
#   'взагалі',
#   'противник',
#   'втрата противник',
#   'бойовий',
#   'загальний',
#   'бойовий втрата',
#   'загальний бойовий'],
#  ['пані',
#   'здаватися',
#   'правда',
#   'країна',
#   'сподіватися',
#   'звісно',
#   'топ',
#   'їхати',
#   'написати',
#   'народження'],
#  ['здаватися',
#   'ізюм',
#   'шукати',
#   'війна',
#   'брати',
#   'втрата',
#   'противник',
#   'десь',
#   'втрата противник',
#   'бойовий'],
#  ['шукати',
#   'пані',
#   'ізюм',
#   'взагалі',
#   'брати',
#   'світ',
#   'чоловік',
#   'правда',
#   'хлопець',
#   'армія'],
#  ['світ',
#   'армія',
#   'здаватися',
#   'армія світ',
#   'область',
#   'взагалі',
#   'найкращий',
#   'анімація',
#   'війна анімація',
#   'місце'],
#  ['чоловік',
#   'брати',
#   'жінка',
#   'хлопець',
#   'дівчина',
#   'світ',
#   'найкращий',
#   'новина',
#   'гроші',
#   'купити'],
#  ['правда',
#   'сподіватися',
#   'світ',
#   'війна',
#   'десь',
#   'новина',
#   'останній',
#   'побачити',
#   'область',
#   'перемога'],
#  ['брати',
#   'дитина',
#   'стати',
#   'рука',
#   'знайти',
#   'область',
#   'місце',
#   'світ',
#   'участь',
#   'ранок'],
#  ['правда',
#   'брати',
#   'анімація',
#   'війна анімація',
#   'чоловік',
#   'вечір',
#   'стати',
#   'давати',
#   'здаватися',
#   'добрий'],
#  ['десь',
#   'кіт',
#   'вечір',
#   'побачити',
#   'сподіватися',
#   'хлопець',
#   'анімація',
#   'війна анімація',
#   'добрий',
#   'добрий вечір'],
#  ['хлопець',
#   'дівчина',
#   'найкращий',
#   'вечір',
#   'дитина',
#   'пані',
#   'хлопець дівчина',
#   'добрий вечір',
#   'точно',
#   'разом'],
#  ['кіт',
#   'забути',
#   'хлопець',
#   'ранок',
#   'правда',
#   'дівчина',
#   'найкращий',
#   'місце',
#   'прийти',
#   'спати'],
#  ['десь',
#   'війна',
#   'місяць',
#   'їхати',
#   'правда',
#   'хотітися',
#   'пані',
#   'новина',
#   'тиждень',
#   'ранок'],
#  ['вечір',
#   'війна',
#   'добрий вечір',
#   'добрий',
#   'забути',
#   'новина',
#   'кіт',
#   'початок',
#   'область',
#   'путін'],
#  ['звісно',
#   'кіт',
#   'твіт',
#   'топ',
#   'читати',
#   'їхати',
#   'вечір',
#   'війна',
#   'дати',
#   'місце'],
#  ['забути',
#   'звісно',
#   'десь',
#   'брати',
#   'виглядати',
#   'ранок',
#   'хлопець',
#   'топ',
#   'пробачити',
#   'росія'],
#  ['прийти',
#   'забути',
#   'осінь',
#   'твіт',
#   'читати',
#   'дати',
#   'гроші',
#   'звісно',
#   'купити',
#   'думка'],
#  ['купити',
#   'гроші',
#   'дати',
#   'річ',
#   'забути',
#   'взяти',
#   'потрібний',
#   'виглядати',
#   'ранок',
#   'ізюм'],
#  ['побачити',
#   'твіт',
#   'дати',
#   'правда',
#   'кіт',
#   'око',
#   'брати',
#   'ранок',
#   'країна',
#   'пані'],
#  ['останній',
#   'тиждень',
#   'дати',
#   'окупант',
#   'місяць',
#   'їхати',
#   'читати',
#   'анімація',
#   'війна анімація',
#   'рука'],
#  ['місце',
#   'перемога',
#   'побачити',
#   'разом',
#   'історія',
#   'взяти',
#   'рука',
#   'сила',
#   'окупант',
#   'їхати'],
#  ['дати',
#   'гроші',
#   'місце',
#   'війна',
#   'стан',
#   'інформація',
#   'тиждень',
#   'місяць',
#   'оперативний',
#   'область'],
#  ['дати',
#   'перемога',
#   'гроші',
#   'разом',
#   'рука',
#   'хотітися',
#   'анімація',
#   'війна анімація',
#   'вірити',
#   'сила'],
#  ['найкращий',
#   'хотітися',
#   'читати',
#   'дати',
#   'твіт',
#   'якось',
#   'думка',
#   'чути',
#   'історія',
#   'бувати'],
#  ['перемога',
#   'найкращий',
#   'разом',
#   'твіт',
#   'якось',
#   'стан',
#   'інформація',
#   'хотітися',
#   'оперативний',
#   'осінь'],
#  ['твіт',
#   'дати',
#   'найкращий',
#   'перемога',
#   'десь',
#   'місце',
#   'сподіватися',
#   'разом',
#   'гроші',
#   'читати'],
#  ['найкращий',
#   'осінь',
#   'побачити',
#   'дати',
#   'звісно',
#   'окупант',
#   'рука',
#   'новина',
#   'написати',
#   'останній'],
#  ['їхати',
#   'рука',
#   'твіт',
#   'купити',
#   'тиждень',
#   'хотітися',
#   'дати',
#   'додому',
#   'скоро',
#   'година'],
#  ['гроші',
#   'їхати',
#   'новина',
#   'хотітися',
#   'потрібний',
#   'армія',
#   'бог',
#   'великий',
#   'друг',
#   'кіт'],
#  ['рука',
#   'твіт',
#   'взяти',
#   'виглядати',
#   'якось',
#   'гроші',
#   'тримати',
#   'друг',
#   'новина',
#   'окупант'],
#  ['хотітися',
#   'рука',
#   'гроші',
#   'взяти',
#   'тиждень',
#   'плакати',
#   'бувати',
#   'твіт',
#   'тримати',
#   'новина'],
#  ['читати',
#   'бувати',
#   'гроші',
#   'їхати',
#   'область',
#   'історія',
#   'останній',
#   'рука',
#   'найкращий',
#   'російський'],
#  ['бувати',
#   'думка',
#   'окупант',
#   'вересень',
#   'гроші',
#   'річ',
#   'осінь',
#   'удар',
#   'мабуть',
#   'чути'],
#  ['виглядати',
#   'бувати',
#   'останній',
#   'новина',
#   'дати',
#   'прийти',
#   'їхати',
#   'твіт',
#   'гарно',
#   'брати'],
#  ['топ',
#   'виглядати',
#   'осінь',
#   'річ',
#   'думка',
#   'гарно',
#   'подивитися',
#   'взяти',
#   'тема',
#   'твітер'],
#  ['думка',
#   'рука',
#   'голова',
#   'дівчина',
#   'тиждень',
#   'їхати',
#   'твітер',
#   'тримати',
#   'купити',
#   'останній'],
#  ['топ',
#   'якось',
#   'бувати',
#   'рука',
#   'подивитися',
#   'тиждень',
#   'твіт',
#   'новина',
#   'тема',
#   'гроші'],
#  ['взяти',
#   'чути',
#   'топ',
#   'друг',
#   'тиждень',
#   'історія',
#   'дівчина',
#   'прийти',
#   'подивитися',
#   'вибух'],
#  ['тиждень',
#   'осінь',
#   'взяти',
#   'бувати',
#   'армія',
#   'скоро',
#   'новина',
#   'російський',
#   'якось',
#   'річ'],
#  ['тиждень',
#   'виглядати',
#   'читати',
#   'гроші',
#   'скоро',
#   'найкращий',
#   'наступний',
#   'місяць',
#   'дівчина',
#   'ходити'],
#  ['читати',
#   'взяти',
#   'бувати',
#   'осінь',
#   'топ',
#   'окупант',
#   'вересень',
#   'якось',
#   'твітер',
#   'стан'],
#  ['річ',
#   'взяти',
#   'бувати',
#   'прийти',
#   'якось',
#   'окупант',
#   'чути',
#   'хотітися',
#   'місяць',
#   'останній'],
#  ['чути',
#   'скоро',
#   'осінь',
#   'гроші',
#   'дівчина',
#   'місяць',
#   'твіт',
#   'вибух',
#   'пісня',
#   'триматися'],
#  ['історія',
#   'подивитися',
#   'разом',
#   'великий',
#   'осінь',
#   'сила',
#   'якось',
#   'дати',
#   'вересень',
#   'мова'],
#  ['скоро',
#   'місяць',
#   'подивитися',
#   'народження',
#   'повернутися',
#   'вдома',
#   'друг',
#   'твітер',
#   'мама',
#   'історія'],
#  ['місяць',
#   'мабуть',
#   'чути',
#   'армія',
#   'разом',
#   'великий',
#   'хотітися',
#   'сила',
#   'твіт',
#   'друг'],
#  ['дівчина',
#   'великий',
#   'друг',
#   'армія',
#   'останній',
#   'путін',
#   'військовий',
#   'вдома',
#   'територія',
#   'мобілізація'],
#  ['подивитися',
#   'великий',
#   'чути',
#   'хлопець',
#   'путін',
#   'мобілізація',
#   'найкращий',
#   'відео',
#   'зеленський',
#   'армія'],
#  ['подивитися',
#   'дівчина',
#   'триматися',
#   'вдома',
#   'окупант',
#   'око',
#   'дніпро',
#   'схожий',
#   'взяти',
#   'мабуть'],
#  ['мама',
#   'великий',
#   'вдома',
#   'разом',
#   'народження',
#   'кава',
#   'друг',
#   'плакати',
#   'сила',
#   'війна'],
#  ['твітер',
#   'великий',
#   'місяць',
#   'окупант',
#   'дівчина',
#   'чути',
#   'мабуть',
#   'око',
#   'кава',
#   'перемога'],
#  ['твітер',
#   'армія',
#   'мама',
#   'вересень',
#   'дніпро',
#   'триматися',
#   'спати',
#   'ніч',
#   'завтра',
#   'кава'],
#  ['народження',
#   'друг',
#   'твітер',
#   'схожий',
#   'потрібний',
#   'жінка',
#   'можливо',
#   'триматися',
#   'окупант',
#   'підтримувати'],
#  ['друг',
#   'схожий',
#   'разом',
#   'армія',
#   'скоро',
#   'сила',
#   'війна',
#   'перемогти',
#   'пан',
#   'лютий'],
#  ['великий',
#   'схожий',
#   'триматися',
#   'друг',
#   'перемога',
#   'пан',
#   'дніпро',
#   'справа',
#   'голова',
#   'тримати'],
#  ['схожий',
#   'вдома',
#   'кава',
#   'голова',
#   'путін',
#   'президент',
#   'мобілізація',
#   'зеленський',
#   'плакати',
#   'пити'],
#  ['схожий',
#   'великий',
#   'окупант',
#   'народження',
#   'армія',
#   'мама',
#   'скоро',
#   'перемога',
#   'взяти',
#   'місяць'],
#  ['око',
#   'триматися',
#   'мама',
#   'територія',
#   'повернутися',
#   'військовий',
#   'твітер',
#   'схожий',
#   'окупований',
#   'жінка'],
#  ['разом',
#   'жінка',
#   'голова',
#   'дніпро',
#   'президент',
#   'схожий',
#   'сила',
#   'удар',
#   'народження',
#   'великий'],
#  ['око',
#   'смерть',
#   'президент',
#   'спати',
#   'плакати',
#   'ворог',
#   'воїн',
#   'вдома',
#   'харк',
#   'зеленський'],
#  ['мама',
#   'друг',
#   'президент',
#   'зеленський',
#   'путін',
#   'можливо',
#   'триматися',
#   'тип',
#   'око',
#   'сила'],
#  ['пан',
#   'русний',
#   'мобілізація',
#   'дніпро',
#   'кава',
#   'путін',
#   'горіти',
#   'територія',
#   'окупований',
#   'пизд'],
#  ['пан',
#   'територія',
#   'президент',
#   'вересень',
#   'окупований',
#   'триматися',
#   'зеленський',
#   'окупований територія',
#   'чоловік',
#   'повернутися'],
#  ['можливо',
#   'жінка',
#   'око',
#   'вибачити',
#   'вересень',
#   'територія',
#   'голова',
#   'говорити',
#   'окупований',
#   'перемога'],
#  ['плакати',
#   'можливо',
#   'вибачити',
#   'тримати',
#   'повернутися',
#   'чоловік',
#   'дівчина',
#   'відео',
#   'триматися',
#   'територія'],
#  ['голова',
#   'смерть',
#   'армія',
#   'ворог',
#   'воїн',
#   'президент',
#   'досі',
#   'твітер',
#   'лютий',
#   'ходити'],
#  ['вибачити',
#   'вдома',
#   'можливо',
#   'дніпро',
#   'потрібний',
#   'жінка',
#   'харк',
#   'русний',
#   'пан',
#   'армія'],
#  ['жінка',
#   'тримати',
#   'плакати',
#   'кава',
#   'пан',
#   'повернутися',
#   'смерть',
#   'гарно',
#   'воїн',
#   'ворог'],
#  ['можливо',
#   'потрібний',
#   'голова',
#   'кава',
#   'мама',
#   'допомога',
#   'смерть',
#   'армія',
#   'пити',
#   'згодний'],
#  ['можливо',
#   'триматися',
#   'завтра',
#   'тримати',
#   'спати',
#   'сила',
#   'ніч',
#   'разом',
#   'жінка',
#   'говорити'],
#  ['кава',
#   'триматися',
#   'вибачити',
#   'пити',
#   'територія',
#   'дніпро',
#   'око',
#   'окупований',
#   'президент',
#   'зеленський'],
#  ['голова',
#   'справа',
#   'окупант',
#   'плакати',
#   'вибачити',
#   'ніч',
#   'русний',
#   'потрібний',
#   'пан',
#   'армія'],
#  ['тримати',
#   'харк',
#   'око',
#   'друг',
#   'плакати',
#   'удар',
#   'армія',
#   'жінка',
#   'голова',
#   'факт'],
#  ['тримати',
#   'вибачити',
#   'гарно',
#   'потрібний',
#   'спати',
#   'смерть',
#   'досі',
#   'разом',
#   'ніч',
#   'відео'],
#  ['вибачити',
#   'путін',
#   'пан',
#   'вдома',
#   'голова',
#   'гарно',
#   'жінка',
#   'друг',
#   'мобілізація',
#   'удар'],
#  ['їсти',
#   'година',
#   'плакати',
#   'спати',
#   'відео',
#   'факт',
#   'норма',
#   'президент',
#   'зеленський',
#   'військовий'],
#  ['справа',
#   'харк',
#   'потрібний',
#   'завтра',
#   'дніпро',
#   'мобілізація',
#   'норма',
#   'повернутися',
#   'тип',
#   'тримати'],
#  ['гарно',
#   'говорити',
#   'почати',
#   'харк',
#   'згодний',
#   'їсти',
#   'мова',
#   'жінка',
#   'потрібний',
#   'досі'],
#  ['їсти',
#   'спати',
#   'харк',
#   'повернутися',
#   'вибачити',
#   'русний',
#   'ніч',
#   'друг',
#   'година',
#   'додому'],
#  ['справа',
#   'гарно',
#   'тип',
#   'ніч',
#   'тримати',
#   'сила',
#   'виходити',
#   'завтра',
#   'спати',
#   'військовий'],
#  ['гарно',
#   'їсти',
#   'голова',
#   'мобілізація',
#   'справа',
#   'потрібний',
#   'земля',
#   'норма',
#   'можливо',
#   'президент'],
#  ['потрібний',
#   'завтра',
#   'плакати',
#   'жінка',
#   'спати',
#   'тип',
#   'година',
#   'територія',
#   'подивитися',
#   'великий'],
#  ['сила',
#   'тип',
#   'триматися',
#   'згодний',
#   'ходити',
#   'харк',
#   'мобілізація',
#   'їсти',
#   'земля',
#   'вірити'],
#  ['тип',
#   'пісня',
#   'повернутися',
#   'дніпро',
#   'ходити',
#   'сила',
#   'додому',
#   'армія',
#   'відео',
#   'гарно'],
#  ['відео',
#   'завтра',
#   'ходити',
#   'русний',
#   'харк',
#   'справа',
#   'досі',
#   'чудовий',
#   'повернутися',
#   'норма'],
#  ['сила',
#   'досі',
#   'згодний',
#   'тримати',
#   'дніпро',
#   'сука',
#   'пісня',
#   'почати',
#   'отримати',
#   'збройний'],
#  ['завтра',
#   'згодний',
#   'їсти',
#   'дніпро',
#   'досі',
#   'тип',
#   'виходити',
#   'норма',
#   'ходити',
#   'плакати'],
#  ['згодний',
#   'факт',
#   'завтра',
#   'голова',
#   'русний',
#   'повернутися',
#   'почати',
#   'потрібний',
#   'відео',
#   'вересень'],
#  ['харк',
#   'тип',
#   'досі',
#   'ніч',
#   'факт',
#   'спати',
#   'відбуватися',
#   'відео',
#   'увага',
#   'існувати'],
#  ['згодний',
#   'ходити',
#   'спати',
#   'горіти',
#   'допомогти',
#   'харк',
#   'військовий',
#   'земля',
#   'пекло',
#   'справа'],
#  ['факт',
#   'досі',
#   'настрій',
#   'ходити',
#   'крим',
#   'допомогти',
#   'згодний',
#   'земля',
#   'цікавий',
#   'ніч'],
#  ['виходити',
#   'мобілізація',
#   'пісня',
#   'спати',
#   'вечір',
#   'сука',
#   'чудовий',
#   'земля',
#   'ранок',
#   'почати'],
#  ['виходити',
#   'допомогти',
#   'згодний',
#   'ніч',
#   'норма',
#   'пісня',
#   'рідний',
#   'залишитися',
#   'слухати',
#   'мова'],
#  ['норма',
#   'пісня',
#   'факт',
#   'допомогти',
#   'отримати',
#   'настрій',
#   'путін',
#   'залишитися',
#   'сука',
#   'ціна'],
#  ['настрій',
#   'хороший',
#   'норма',
#   'ніч',
#   'почати',
#   'мобілізація',
#   'крим',
#   'пісня',
#   'русний',
#   'відбуватися'],
#  ['спати',
#   'факт',
#   'почати',
#   'цікавий',
#   'година',
#   'норма',
#   'отримати',
#   'дніпро',
#   'початок',
#   'допомогти'],
#  ['хороший',
#   'земля',
#   'завтра',
#   'виходити',
#   'підтримувати',
#   'цікавий',
#   'варіант',
#   'отримати',
#   'плакати',
#   'допомогти'],
#  ['чудовий',
#   'виходити',
#   'почати',
#   'план',
#   'факт',
#   'настрій',
#   'військовий',
#   'ніч',
#   'харк',
#   'починати'],
#  ['мобілізація',
#   'година',
#   'завтра',
#   'відбуватися',
#   'норма',
#   'добрий',
#   'почати',
#   'сука',
#   'іти',
#   'допомогти'],
#  ['земля',
#   'говорити',
#   'пісня',
#   'дніпро',
#   'перемогти',
#   'зброя',
#   'година',
#   'ядерний',
#   'харк',
#   'русний'],
#  ['сука',
#   'мова',
#   'відбуватися',
#   'кращий',
#   'спати',
#   'допомогти',
#   'подумати',
#   'допомога',
#   'пісня',
#   'заїбати'],
#  ['вибух',
#   'вірити',
#   'ніч',
#   'відбуватися',
#   'питати',
#   'чудовий',
#   'смачний',
#   'вечір',
#   'привіт',
#   'година'],
#  ['почати',
#   'відбуватися',
#   'ніч',
#   'норма',
#   'народ',
#   'план',
#   'хуйня',
#   'увага',
#   'сука',
#   'крим'],
#  ['пісня',
#   'година',
#   'почати',
#   'хороший',
#   'план',
#   'допомогти',
#   'показати',
#   'ніч',
#   'вчора',
#   'досі'],
#  ['сука',
#   'народ',
#   'перемогти',
#   'година',
#   'вірити',
#   'лютий',
#   'сидіти',
#   'питати',
#   'зброя',
#   '24'],
#  ['вибух',
#   'факт',
#   'допомогти',
#   'пісня',
#   'ядерний',
#   'кращий',
#   'зброя',
#   'спати',
#   'підтримувати',
#   'тривога'],
#  ['почати',
#   'вечір',
#   'вірити',
#   'ранок',
#   'земля',
#   'підтримувати',
#   'існувати',
#   'подумати',
#   'привіт',
#   'норма'],
#  ['крим',
#   'підтримувати',
#   'народ',
#   'чудовий',
#   'ніч',
#   'норма',
#   'варіант',
#   'досі',
#   'просити',
#   'перемогти'],
#  ['кращий',
#   'сука',
#   'вічний',
#   'память',
#   'почати',
#   'вічний память',
#   'земля',
#   'починати',
#   'увага',
#   'память герой'],
#  ['крим',
#   'проблема',
#   'лютий',
#   'чудовий',
#   'мова',
#   '24',
#   'отримати',
#   '24 лютий',
#   'початок',
#   'залишитися'],
#  ['проблема',
#   'чудовий',
#   'пане',
#   'допомогти',
#   'головне',
#   'сука',
#   'пити',
#   'намагатися',
#   'варіант',
#   'прекрасний'],
#  ['отримати',
#   'підтримувати',
#   'пане',
#   'привіт',
#   'віріти',
#   'район',
#   'починати',
#   'перемогти',
#   'мова',
#   'обстріл'],
#  ['чудовий',
#   'заїбати',
#   'сила',
#   'віріти',
#   'факт',
#   'кращий',
#   'лютий',
#   'удар',
#   'привіт',
#   'існувати'],
#  ['підтримувати',
#   'значити',
#   'існувати',
#   'година',
#   'цікавий',
#   'гірше',
#   'вибух',
#   'початок',
#   'відчувати',
#   'щастя'],
#  ['існувати',
#   'вибух',
#   'привіт',
#   'мова',
#   'початок',
#   'тривога',
#   'приємно',
#   'головне',
#   'земля',
#   'увага'],
#  ['увага',
#   'вірити',
#   'підтримувати',
#   'почати',
#   'сидіти',
#   'мова',
#   'слухати',
#   'досі',
#   'старий',
#   'котик'],
#  ['головне',
#   'слухати',
#   'увага',
#   'початок',
#   'сука',
#   'привіт',
#   'говорити',
#   'обстріл',
#   'боляче',
#   'залишитися'],
#  ['боляче',
#   'вірити',
#   'план',
#   'вибух',
#   'початок',
#   'улюблений',
#   'рідний',
#   'підтримувати',
#   'увага',
#   'ціна'],
#  ['варіант',
#   'існувати',
#   'проблема',
#   'сидіти',
#   'гірше',
#   'район',
#   'відповідь',
#   'вірити',
#   'привіт',
#   'ласка'],
#  ['привіт',
#   'вибух',
#   'показати',
#   'питати',
#   'пакет',
#   'проблема',
#   'приємно',
#   'перемогти',
#   'класний',
#   'підтримувати'],
#  ['план',
#   'проблема',
#   'починати',
#   'смачний',
#   'перемогти',
#   'відчувати',
#   'вчора',
#   'полон',
#   'грати',
#   'ціна'],
#  ['слухати',
#   'цікавий',
#   'сидіти',
#   'варіант',
#   'пити',
#   'кращий',
#   'ситуація',
#   'полон',
#   'ласка',
#   'різний'],
#  ['слухати',
#   'вчора',
#   'вірити',
#   'показати',
#   'рідний',
#   'цікавий',
#   'сидіти',
#   'чудовий',
#   'мова',
#   'проблема'],
#  ['початок',
#   'перемогти',
#   'план',
#   'гірше',
#   'вчора',
#   'допомогти',
#   'повернутися',
#   'подумати',
#   'красивий',
#   'улюблений'],
#  ['питати',
#   'рідний',
#   'заїбати',
#   'школа',
#   'сидіти',
#   'готовий',
#   'твіттер',
#   'головне',
#   'факт',
#   'показувати'],
#  ['план',
#   'хуйня',
#   'прекрасний',
#   'вітання',
#   'пити',
#   'красивий',
#   'котик',
#   'показувати',
#   'відчувати',
#   'жарт'],
#  ['перемогти',
#   'котик',
#   'красивий',
#   'ласка',
#   'проблема',
#   'боляче',
#   'віріти',
#   'приємно',
#   'зброя',
#   'привіт'],
#  ['боляче',
#   'подумати',
#   'показати',
#   'ситуація',
#   'питати',
#   'блін',
#   'хуйня',
#   'класний',
#   'допомогти',
#   'ласка'],
#  ['пити',
#   'вчора',
#   'народ',
#   'приємно',
#   'поїхати',
#   'подумати',
#   'серце',
#   'допомогти',
#   'ніч',
#   'боляче'],
#  ['приємно',
#   'гірше',
#   'пане',
#   'цікавий',
#   'рідний',
#   'зброя',
#   'серце',
#   'показати',
#   'початок',
#   'відчувати'],
#  ['заїбати',
#   'план',
#   'головне',
#   'боляче',
#   'смачний',
#   'тривога',
#   'приємно',
#   'варіант',
#   'залишитися',
#   'показати'],
#  ['варіант',
#   'нахувати',
#   'перемогти',
#   'цікавий',
#   'боляче',
#   'значити',
#   'залишитися',
#   'прекрасний',
#   'питати',
#   'шкода'],
#  ['відчувати',
#   'показати',
#   'рашист',
#   'варіант',
#   'боятися',
#   'приїхати',
#   'починати',
#   'мова',
#   'різний',
#   'допомогти'],
#  ['гірше',
#   'нахувати',
#   'пити',
#   'приємно',
#   'співчувати',
#   'школа',
#   'твіттер',
#   'поїхати',
#   'головне',
#   'колись'],
#  ['значити',
#   'статися',
#   'тривога',
#   'віріти',
#   'грати',
#   'цікавий',
#   'блін',
#   'ситуація',
#   'сидіти',
#   'готовий'],
#  ['заїбати',
#   'хуйня',
#   'старий',
#   'рідний',
#   'повернення',
#   'пакет',
#   'спробувати',
#   'шкода',
#   'відповідь',
#   'пройти'],
#  ['повернення',
#   'відповідь',
#   'смачний',
#   'дощ',
#   'прекрасний',
#   'значити',
#   'вчора',
#   'починати',
#   'хвилина',
#   'неймовірний'],
#  ['значити',
#   'вітання',
#   'терорист',
#   'починати',
#   'варіант',
#   'показати',
#   'грати',
#   'улюблений',
#   'намагатися',
#   'ціна'],
#  ['тупо',
#   'хуйня',
#   'проблема',
#   'терорист',
#   'залишитися',
#   'твіттер',
#   'головне',
#   'вчора',
#   'починати',
#   'гірше'],
#  ['вітання',
#   'старий',
#   'приїхати',
#   'ситуація',
#   'боятися',
#   'смачний',
#   'право',
#   'хуйня',
#   'село',
#   'звільнити'],
#  ['залишитися',
#   'вітання',
#   'сидіти',
#   'старий',
#   'насправді',
#   'полон',
#   'пункт',
#   'нахувати',
#   'подумати',
#   'привіт']]

# %%
with open('coherences_12grams_uk_new_pos.json','w') as json_file:
    json.dump({'coherences': coherences_12grams,
               'predicted_topics': predicted_topics_counts_12grams}, json_file)

# %%
plt.plot(topic_numbers_12grams, coherences_12grams)
plt.title('Coherence for different n_topics | 12grams model, new preprocessing, only certain PoS | Ukrainian')
plt.xlabel('Topics number')
plt.ylabel('Coherence (c_v) score')
plt.grid()
plt.show()

# %% [markdown]
# # Plotting pipeline example and functions

# %%
coherences_12grams, predicted_topics_counts_12grams = calculate_coherence_for_plots(
    list(range(2,15)) + [20,30,40,50,100,150,200],
    texts_v4,
    dictionary_v4,
    LSAPipelineUkrainian_v3,
    preprocessed_documents_pos,
    n_top_words=10,
    ngram_range=(1,2),
    filter_by_pos=['NOUN','PNOUN','VERB','ADJ','ADV']
    tf_idf_max_df=0.9,
    tf_idf_min_df=4,
    coherence_type='c_v',
    processes=4,
    random_state=47,
    save_name='12grams_uk_new_pos',
    verbose=1
)

# %%
def calculate_coherence_for_plots(topic_numbers: list, texts,
                                  dictionary, lsa_pipeline,
                                  preprocessed_documents_list,
                                  n_top_words,
                                  ngram_range = (1,1),
                                  filter_by_pos = [],
                                  tf_idf_max_df = 0.9,
                                  tf_idf_min_df = 4,
                                  coherence_type: str = 'c_v',
                                  processes: int = 1
                                  random_state = 0,
                                  save_name = False,
                                  verbose: int = 0):
    coherences = []
    predicted_topics_counts = []
    for topic_number in topic_numbers:
        LSAPipeline = lsa_pipeline(preprocessed_documents_list, tf_idf_max_df=tf_idf_max_df,
                                   tf_idf_min_df=tf_idf_min_df,
                                   lsa_components=topic_number, svd_n_iter=5,
                                   n_top_words=n_top_words, ngram_range=ngram_range,
                                   filter_by_pos=filter_by_pos,
                                   import_preprocessed_documents=True, random_state=random_state)
        topics = LSAPipeline.run_topics_detection()
        tfidf_feature_names = set(LSAPipeline.tfidf_vectorizer.get_feature_names_out())
        # Calculate the coherence score using Gensim
        coherence_model = CoherenceModel(topics=topics,
                                         texts=texts,
                                         dictionary=dictionary,
                                         coherence=coherence_type,
                                         processes=processes)
        coherence_score = coherence_model.get_coherence()
        predicted_topics = LSAPipeline.transform_documents(LSAPipeline.import_documents_list)
        predicted_topics_count = [predicted_topics.count(x) for x in np.sort(np.unique(predicted_topics))]
        if verbose == 1:
            print(f'--Topic number {topic_number} coherence score: {coherence_score}')
        coherences.append(coherence_score)
        predicted_topics_counts.append(predicted_topics_count)
    if save_name:
        with open('coherences_{save_name}.json','w') as json_file:
            json.dump({'coherences': coherences,
                       'predicted_topics': predicted_topics_counts}, json_file)
    return coherences, predicted_topics_counts

# %%
plot_coherences(
    list(range(2,15)) + [20,30,40,50,100,150,200],
    coherences_12grams,
    '12grams model, new preprocessing, only certain PoS',
    'Ukrainian'
)

# %%
def plot_coherences(topic_numbers, coherences,
                    plot_description: str = '',
                    lang_description: str = 'Ukrainian'):
    plt.plot(topic_numbers, coherences)
    plt.title(f'Coherence for different n_topics | {plot_description} | {lang_description}')
    plt.xlabel('Topics number')
    plt.ylabel('Coherence (c_v) score')
    plt.grid()
    plt.show()
